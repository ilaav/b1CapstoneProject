# %% [markdown]
# #### Importing the required libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
from functools import reduce
import scipy.stats as st

# %% [markdown]
# #### Importing required dataset

# %%
city_master = pd.read_csv('City_Master.csv')
cust_and_bank_det = pd.read_csv('Customer_and_bank details_p1.csv')
cust_camp_det = pd.read_csv('Customer_campaign_details_p1.csv')
cust_post_code_det = pd.read_csv('Customer_Postal_Code_details.csv')
cust_resp_data = pd.read_csv('Customer_Response_data_p1.csv')
cust_social_eco_data = pd.read_csv('Customer_social_economic_data_p1.csv')
reg_code_master = pd.read_csv('Region_code_master.csv')
state_master = pd.read_csv('State_Master.csv')

# %% [markdown]
# # TASK 1.1: Analysis of Percentage Turnout of Marketing Campaign

# %% [markdown]
# #### Joining customer response data with customer campaign data and getting insights and drawing conclusion on percentage turnout

# %%
df1 = pd.merge(cust_resp_data, cust_camp_det, on='Customer_id', how='outer')

# %% [markdown]
# Display the joined dataset

# %%
display(df1)
# Out:
#        Customer_id    y    contact month day_of_week  duration  campaign  \
# 0                1   no  telephone   may         mon       307         1
# 1                2   no  telephone   may         mon       198         1
# 2                3   no  telephone   may         mon       139         1
# 3                4   no  telephone   may         mon       217         1
# 4                5   no  telephone   may         mon       380         1
# ...            ...  ...        ...   ...         ...       ...       ...
# 37079        37080  yes   cellular   nov         fri       334         1
# 37080        37081   no   cellular   nov         fri       383         1
# 37081        37082   no   cellular   nov         fri       189         2
# 37082        37083  yes   cellular   nov         fri       442         1
# 37083        37084   no   cellular   nov         fri       239         3
#
#        pdays  previous     poutcome
# 0        999         0  nonexistent
# 1        999         0  nonexistent
# 2        999         0  nonexistent
# 3        999         0  nonexistent
# 4        999         0  nonexistent
# ...      ...       ...          ...
# 37079    999         0  nonexistent
# 37080    999         0  nonexistent
# 37081    999         0  nonexistent
# 37082    999         0  nonexistent
# 37083    999         1      failure
#
# [37084 rows x 10 columns]

# %% [markdown]
# Find out the response distribution for the campaign

# %%
response = df1['y'].value_counts()
display(response)
# Out:
# no     32876
# yes     4208
# Name: y, dtype: int64

# %% [markdown]
# INFERENCE: It is found that 11.3% out of the total people who were targeted through the campaign responded 'Yes'.

# %% [markdown]
# #### Right mode to Contact the Customers (Telephone or Cellular)

# %% [markdown]
# Analysing the mode of contacting the customers [cellular vs telephone]

# %%
resp_contact = df1['contact'].value_counts()

# %%
print(resp_contact)
# Out:
# cellular     23522
# telephone    13562
# Name: contact, dtype: int64

# %% [markdown]
# Filtering the customers who were contacted via telephone and responded 'yes'

# %%
tel_yes = df1[["contact", "y"]].loc[(df1["contact"] == "telephone") & (df1["y"]=="yes")]

# %% [markdown]
# Filtering the customers who were contacted via telephone and responded 'No'

# %%
tel_no = df1[["contact", "y"]].loc[(df1["contact"] == "telephone") & (df1["y"]=="no")]

# %% [markdown]
# Filtering the customers who were contacted via telephone

# %%
tel =  df1[["contact", "y"]].loc[(df1["contact"] == "telephone")]
tel
tel.value_counts()
# Out:
# contact    y
# telephone  no     12846
#            yes      716
# dtype: int64

# %% [markdown]
# #### Remove Graphs

# %% [markdown]
# Filtering the customers who were contacted via cellular and responded 'yes'

# %%
cellular =  df1[["contact", "y"]].loc[(df1["contact"] == "cellular")]
cellular.value_counts()
# Out:
# contact   y
# cellular  no     20030
#           yes     3492
# dtype: int64

# %%
cellular.groupby('y').size().plot.pie(autopct='%1.1f%%', title="Cellular Response", labels = ['No', 'Yes'], ylabel="", explode = myexplode)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-3d7922b6ff5d> in <module>
# ----> 1 cellular.groupby('y').size().plot.pie(autopct='%1.1f%%', title="Cellular Response", labels = ['No', 'Yes'], ylabel="", explode = myexplode)
#
# NameError: name 'myexplode' is not defined

# %% [markdown]
# Visualising the combined result for analysis of mode of Contact

# %%
df_telephone = df1.groupby(['contact', 'y'])['Customer_id'].count().unstack()

# %%
display(df_telephone)
# Out:
# y             no   yes
# contact
# cellular   20030  3492
# telephone  12846   716

# %%
df_telephone.plot(kind='bar', stacked=True, width=0.3, figsize=[6,6], ylabel="No. of customers",xlabel="Mode Of Contact")
# Out:
# <AxesSubplot:xlabel='Mode Of Contact', ylabel='No. of customers'>

# %% [markdown]
# INFERENCE: It was found that 14.8% of the people who were contacted via cellular responded 'Yes' in comparison to 5.3% who were contacted via telephone. Hence we can infer that Cellular is a better mode of contact.

# %% [markdown]
# #### Analysis on attempts made to turn a person into successful depositor

# %%
success = df1[(df1['y']=="yes") & ((df1['poutcome']=="failure") | (df1['poutcome']=="nonexistent"))]

# %%
display(success)
# Out:
#        Customer_id    y    contact month day_of_week  duration  campaign  \
# 68              69  yes  telephone   may         mon      1575         1
# 75              76  yes  telephone   may         mon      1042         1
# 79              80  yes  telephone   may         mon      1467         1
# 120            121  yes  telephone   may         mon       579         1
# 258            259  yes  telephone   may         mon       935         3
# ...            ...  ...        ...   ...         ...       ...       ...
# 37070        37071  yes   cellular   nov         thu       353         1
# 37071        37072  yes   cellular   nov         thu       329         1
# 37078        37079  yes   cellular   nov         fri       281         1
# 37079        37080  yes   cellular   nov         fri       334         1
# 37082        37083  yes   cellular   nov         fri       442         1
#
#        pdays  previous     poutcome
# 68       999         0  nonexistent
# 75       999         0  nonexistent
# 79       999         0  nonexistent
# 120      999         0  nonexistent
# 258      999         0  nonexistent
# ...      ...       ...          ...
# 37070    999         0  nonexistent
# 37071    999         2      failure
# 37078    999         0  nonexistent
# 37079    999         0  nonexistent
# 37082    999         0  nonexistent
#
# [3393 rows x 10 columns]

# %% [markdown]
# Count of all rows in poutcome

# %%
display(success.Customer_id.count())
# Out:
# 3393

# %% [markdown]
# INFERENCE: 3393 people who had given a negative reponse or had not participated in the previous campaign turned into successful depositors in this campaign.

# %%
succ1 = success.groupby(['campaign'])['Customer_id'].count()
succ1
# Out:
# campaign
# 1     1646
# 2      853
# 3      429
# 4      212
# 5      101
# 6       59
# 7       31
# 8       14
# 9       13
# 10      10
# 11      11
# 12       3
# 13       3
# 14       1
# 15       2
# 17       4
# 23       1
# Name: Customer_id, dtype: int64

# %%
succ1.plot(kind='bar', figsize=[6,6], ylabel="No. of customers",xlabel="No of Attempts")
# Out:
# <AxesSubplot:xlabel='No of Attempts', ylabel='No. of customers'>

# %% [markdown]
# INFERENCE: 3393 people who responded 'Yes' for the current campaign but 'No' for the previous one. Out of these, 1646 people got converted in the 1st attempt, and 853 people in the 2nd attempt. Looking at the trend it can be inferred that people who agree to deposit generally agree in 1st few attempts.

# %% [markdown]
# Analysis based on 'campaign' - number of contacts performed during this campaign and for this client (includes last contact)

# %%
attempt_camp = df1.groupby(['campaign', 'y'])['Customer_id'].count().unstack()

# %%
#attempt_camp.plot(kind='barh', stacked=True, figsize=[25,25])
#attempt_camp.groupby(['campaign','y']).size().plot.barh(label='Number of Attempts', stacked=True)

# %%
#attempt_camp =  df1[["y", "campaign"]].loc[(df1["y"] == "no")]
#attempt_camp.groupby('campaign').size().plot.pie(label='Number of Attempts', autopct='%1.1f%%')

# %% [markdown]
# This is actual imp graph. Shows no. of contacts DURING THIS campaign.

# %%
att_camp = df1.groupby(['campaign', 'y'])['Customer_id'].count().unstack()
att_camp
# Out:
# y              no     yes
# campaign
# 1         13793.0  2090.0
# 2          8438.0  1094.0
# 3          4262.0   515.0
# 4          2154.0   235.0
# 5          1331.0   110.0
# 6           804.0    69.0
# 7           547.0    33.0
# 8           346.0    14.0
# 9           247.0    13.0
# 10          186.0    10.0
# 11          154.0    11.0
# 12          115.0     3.0
# 13           85.0     3.0
# 14           61.0     1.0
# 15           39.0     2.0
# 16           45.0     NaN
# 17           45.0     4.0
# 18           32.0     NaN
# 19           25.0     NaN
# 20           28.0     NaN
# 21           24.0     NaN
# 22           14.0     NaN
# 23           13.0     1.0
# 24           14.0     NaN
# 25            6.0     NaN
# 26            7.0     NaN
# 27            9.0     NaN
# 28            8.0     NaN
# 29            8.0     NaN
# 30            6.0     NaN
# 31            6.0     NaN
# 32            4.0     NaN
# 33            4.0     NaN
# 34            3.0     NaN
# 35            4.0     NaN
# 37            1.0     NaN
# 39            1.0     NaN
# 40            2.0     NaN
# 41            1.0     NaN
# 42            1.0     NaN
# 43            2.0     NaN
# 56            1.0     NaN

# %% [markdown]
# INFERENCE: 13793 people responded "Yes" to the campaign within the firt atempt of contacting them, while 2090 people responded with a "No'. The highest success was recorded when people were contacted once.

# %%
# Plotting Bar Chart 
att_camp.plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='campaign'>

# %% [markdown]
# #### Not Important

# %%
attempt_pout =  df1[["y", "poutcome"]].loc[(df1["y"] == "yes")]

# %%
attempt_pout.groupby('poutcome').size().plot.pie(label='Number of Attempts', autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Number of Attempts'>

# %% [markdown]
# Shows how many got converted/continued depositing. Don't know if it's imp or not

# %% [markdown]
# #### Personal Data Analysis

# %% [markdown]
# Joining customer response data table with customer and bank details table

# %%
df4 = pd.merge(cust_resp_data, cust_and_bank_det, on='Customer_id', how='outer')

# %%
df4
# Out:
#        Customer_id    y  age          job  marital            education  \
# 0                1   no   56     services  married          high.school
# 1                2   no   45     services  married             basic.9y
# 2                3   no   59       admin.  married  professional.course
# 3                4   no   41  blue-collar  married              unknown
# 4                5   no   24   technician   single  professional.course
# ...            ...  ...  ...          ...      ...                  ...
# 37079        37080  yes   73      retired  married  professional.course
# 37080        37081   no   46  blue-collar  married  professional.course
# 37081        37082   no   56      retired  married    university.degree
# 37082        37083  yes   44   technician  married  professional.course
# 37083        37084   no   74      retired  married  professional.course
#
#        default housing loan Region_Code State_Code City_Code
# 0           no      no  yes           3         S1        C1
# 1      unknown      no   no           3         S1        C1
# 2           no      no   no           4         S2        C2
# 3      unknown      no   no           3         S3        C3
# 4           no     yes   no           3         S3        C3
# ...        ...     ...  ...         ...        ...       ...
# 37079       no     yes   no           2        S16       C21
# 37080       no      no   no           2        S16       C21
# 37081       no     yes   no           2        S16       C21
# 37082       no      no   no           4        S17       C49
# 37083       no     yes   no           1         S6      C113
#
# [37084 rows x 12 columns]

# %%
combine1 = df4[['y','job','education']]
#.loc[(df4["y"] == "yes")]
c1=combine1.groupby(['y','education','job'])
list(c1)
#.count().unstack()
#c1.plot(kind='bar', stacked=True, figsize=[25,25])
# Out:
# [(('no', 'basic.4y', 'admin.'),
#           y     job education
#   418    no  admin.  basic.4y
#   702    no  admin.  basic.4y
#   910    no  admin.  basic.4y
#   911    no  admin.  basic.4y
#   914    no  admin.  basic.4y
#   ...    ..     ...       ...
#   31719  no  admin.  basic.4y
#   32069  no  admin.  basic.4y
#   32744  no  admin.  basic.4y
#   34297  no  admin.  basic.4y
#   36449  no  admin.  basic.4y
#
#   [63 rows x 3 columns]),
#  (('no', 'basic.4y', 'blue-collar'),
#           y          job education
#   16     no  blue-collar  basic.4y
#   27     no  blue-collar  basic.4y
#   47     no  blue-collar  basic.4y
#   62     no  blue-collar  basic.4y
#   72     no  blue-collar  basic.4y
#   ...    ..          ...       ...
#   36458  no  blue-collar  basic.4y
#   36472  no  blue-collar  basic.4y
#   36572  no  blue-collar  basic.4y
#   36821  no  blue-collar  basic.4y
#   37060  no  blue-collar  basic.4y
#
#   [1983 rows x 3 columns]),
#  (('no', 'basic.4y', 'entrepreneur'),
#           y           job education
#   321    no  entrepreneur  basic.4y
#   368    no  entrepreneur  basic.4y
#   375    no  entrepreneur  basic.4y
#   648    no  entrepreneur  basic.4y
#   878    no  entrepreneur  basic.4y
#   ...    ..           ...       ...
#   30830  no  entrepreneur  basic.4y
#   32885  no  entrepreneur  basic.4y
#   33561  no  entrepreneur  basic.4y
#   34564  no  entrepreneur  basic.4y
#   34576  no  entrepreneur  basic.4y
#
#   [112 rows x 3 columns]),
#  (('no', 'basic.4y', 'housemaid'),
#           y        job education
#   9      no  housemaid  basic.4y
#   44     no  housemaid  basic.4y
#   127    no  housemaid  basic.4y
#   195    no  housemaid  basic.4y
#   198    no  housemaid  basic.4y
#   ...    ..        ...       ...
#   36717  no  housemaid  basic.4y
#   36825  no  housemaid  basic.4y
#   36829  no  housemaid  basic.4y
#   36863  no  housemaid  basic.4y
#   36914  no  housemaid  basic.4y
#
#   [379 rows x 3 columns]),
#  (('no', 'basic.4y', 'management'),
#           y         job education
#   26     no  management  basic.4y
#   211    no  management  basic.4y
#   340    no  management  basic.4y
#   341    no  management  basic.4y
#   564    no  management  basic.4y
#   ...    ..         ...       ...
#   34535  no  management  basic.4y
#   34551  no  management  basic.4y
#   34795  no  management  basic.4y
#   34805  no  management  basic.4y
#   35288  no  management  basic.4y
#
#   [84 rows x 3 columns]),
#  (('no', 'basic.4y', 'retired'),
#           y      job education
#   119    no  retired  basic.4y
#   367    no  retired  basic.4y
#   429    no  retired  basic.4y
#   508    no  retired  basic.4y
#   590    no  retired  basic.4y
#   ...    ..      ...       ...
#   36887  no  retired  basic.4y
#   36891  no  retired  basic.4y
#   36902  no  retired  basic.4y
#   36904  no  retired  basic.4y
#   36908  no  retired  basic.4y
#
#   [365 rows x 3 columns]),
#  (('no', 'basic.4y', 'self-employed'),
#           y            job education
#   658    no  self-employed  basic.4y
#   917    no  self-employed  basic.4y
#   2066   no  self-employed  basic.4y
#   2699   no  self-employed  basic.4y
#   2745   no  self-employed  basic.4y
#   ...    ..            ...       ...
#   29644  no  self-employed  basic.4y
#   29815  no  self-employed  basic.4y
#   30279  no  self-employed  basic.4y
#   32151  no  self-employed  basic.4y
#   32205  no  self-employed  basic.4y
#
#   [81 rows x 3 columns]),
#  (('no', 'basic.4y', 'services'),
#           y       job education
#   189    no  services  basic.4y
#   320    no  services  basic.4y
#   558    no  services  basic.4y
#   586    no  services  basic.4y
#   1279   no  services  basic.4y
#   ...    ..       ...       ...
#   31532  no  services  basic.4y
#   31831  no  services  basic.4y
#   32760  no  services  basic.4y
#   32781  no  services  basic.4y
#   35517  no  services  basic.4y
#
#   [110 rows x 3 columns]),
#  (('no', 'basic.4y', 'student'),
#           y      job education
#   3031   no  student  basic.4y
#   6252   no  student  basic.4y
#   6512   no  student  basic.4y
#   12490  no  student  basic.4y
#   12491  no  student  basic.4y
#   12493  no  student  basic.4y
#   12495  no  student  basic.4y
#   25170  no  student  basic.4y
#   25699  no  student  basic.4y
#   27157  no  student  basic.4y
#   27283  no  student  basic.4y
#   27342  no  student  basic.4y
#   29933  no  student  basic.4y
#   35660  no  student  basic.4y
#   35932  no  student  basic.4y),
#  (('no', 'basic.4y', 'technician'),
#           y         job education
#   32     no  technician  basic.4y
#   203    no  technician  basic.4y
#   253    no  technician  basic.4y
#   365    no  technician  basic.4y
#   399    no  technician  basic.4y
#   400    no  technician  basic.4y
#   402    no  technician  basic.4y
#   491    no  technician  basic.4y
#   493    no  technician  basic.4y
#   610    no  technician  basic.4y
#   806    no  technician  basic.4y
#   809    no  technician  basic.4y
#   2061   no  technician  basic.4y
#   2917   no  technician  basic.4y
#   3415   no  technician  basic.4y
#   4140   no  technician  basic.4y
#   4146   no  technician  basic.4y
#   5622   no  technician  basic.4y
#   5931   no  technician  basic.4y
#   6336   no  technician  basic.4y
#   6414   no  technician  basic.4y
#   6723   no  technician  basic.4y
#   7037   no  technician  basic.4y
#   8378   no  technician  basic.4y
#   8504   no  technician  basic.4y
#   8725   no  technician  basic.4y
#   8891   no  technician  basic.4y
#   9211   no  technician  basic.4y
#   10892  no  technician  basic.4y
#   10897  no  technician  basic.4y
#   15129  no  technician  basic.4y
#   15550  no  technician  basic.4y
#   16009  no  technician  basic.4y
#   16188  no  technician  basic.4y
#   22666  no  technician  basic.4y
#   23224  no  technician  basic.4y
#   24401  no  technician  basic.4y
#   24512  no  technician  basic.4y
#   24649  no  technician  basic.4y
#   24652  no  technician  basic.4y
#   26408  no  technician  basic.4y
#   30304  no  technician  basic.4y
#   31007  no  technician  basic.4y
#   34403  no  technician  basic.4y
#   34409  no  technician  basic.4y
#   34411  no  technician  basic.4y
#   34725  no  technician  basic.4y),
#  (('no', 'basic.4y', 'unemployed'),
#           y         job education
#   102    no  unemployed  basic.4y
#   408    no  unemployed  basic.4y
#   668    no  unemployed  basic.4y
#   680    no  unemployed  basic.4y
#   903    no  unemployed  basic.4y
#   ...    ..         ...       ...
#   34380  no  unemployed  basic.4y
#   34898  no  unemployed  basic.4y
#   35011  no  unemployed  basic.4y
#   35806  no  unemployed  basic.4y
#   36718  no  unemployed  basic.4y
#
#   [89 rows x 3 columns]),
#  (('no', 'basic.4y', 'unknown'),
#           y      job education
#   28     no  unknown  basic.4y
#   1036   no  unknown  basic.4y
#   1096   no  unknown  basic.4y
#   1491   no  unknown  basic.4y
#   1499   no  unknown  basic.4y
#   2047   no  unknown  basic.4y
#   2197   no  unknown  basic.4y
#   2237   no  unknown  basic.4y
#   3342   no  unknown  basic.4y
#   3513   no  unknown  basic.4y
#   5377   no  unknown  basic.4y
#   5702   no  unknown  basic.4y
#   5869   no  unknown  basic.4y
#   6917   no  unknown  basic.4y
#   7478   no  unknown  basic.4y
#   8296   no  unknown  basic.4y
#   8748   no  unknown  basic.4y
#   8765   no  unknown  basic.4y
#   9268   no  unknown  basic.4y
#   9317   no  unknown  basic.4y
#   10597  no  unknown  basic.4y
#   10851  no  unknown  basic.4y
#   11355  no  unknown  basic.4y
#   12052  no  unknown  basic.4y
#   13254  no  unknown  basic.4y
#   15235  no  unknown  basic.4y
#   15318  no  unknown  basic.4y
#   20887  no  unknown  basic.4y
#   20941  no  unknown  basic.4y
#   20958  no  unknown  basic.4y
#   21004  no  unknown  basic.4y
#   21018  no  unknown  basic.4y
#   23292  no  unknown  basic.4y
#   27075  no  unknown  basic.4y
#   27076  no  unknown  basic.4y
#   27088  no  unknown  basic.4y
#   27106  no  unknown  basic.4y
#   27125  no  unknown  basic.4y
#   29844  no  unknown  basic.4y
#   29858  no  unknown  basic.4y
#   32457  no  unknown  basic.4y
#   32458  no  unknown  basic.4y
#   32461  no  unknown  basic.4y
#   32609  no  unknown  basic.4y
#   34395  no  unknown  basic.4y
#   36074  no  unknown  basic.4y),
#  (('no', 'basic.6y', 'admin.'),
#           y     job education
#   117    no  admin.  basic.6y
#   161    no  admin.  basic.6y
#   274    no  admin.  basic.6y
#   289    no  admin.  basic.6y
#   475    no  admin.  basic.6y
#   ...    ..     ...       ...
#   32099  no  admin.  basic.6y
#   32318  no  admin.  basic.6y
#   32319  no  admin.  basic.6y
#   34436  no  admin.  basic.6y
#   34462  no  admin.  basic.6y
#
#   [125 rows x 3 columns]),
#  (('no', 'basic.6y', 'blue-collar'),
#           y          job education
#   10     no  blue-collar  basic.6y
#   12     no  blue-collar  basic.6y
#   13     no  blue-collar  basic.6y
#   55     no  blue-collar  basic.6y
#   56     no  blue-collar  basic.6y
#   ...    ..          ...       ...
#   35848  no  blue-collar  basic.6y
#   36039  no  blue-collar  basic.6y
#   36138  no  blue-collar  basic.6y
#   36250  no  blue-collar  basic.6y
#   36539  no  blue-collar  basic.6y
#
#   [1197 rows x 3 columns]),
#  (('no', 'basic.6y', 'entrepreneur'),
#           y           job education
#   152    no  entrepreneur  basic.6y
#   488    no  entrepreneur  basic.6y
#   1134   no  entrepreneur  basic.6y
#   1138   no  entrepreneur  basic.6y
#   1259   no  entrepreneur  basic.6y
#   1904   no  entrepreneur  basic.6y
#   2354   no  entrepreneur  basic.6y
#   3268   no  entrepreneur  basic.6y
#   3412   no  entrepreneur  basic.6y
#   3945   no  entrepreneur  basic.6y
#   4098   no  entrepreneur  basic.6y
#   4493   no  entrepreneur  basic.6y
#   4521   no  entrepreneur  basic.6y
#   4726   no  entrepreneur  basic.6y
#   4741   no  entrepreneur  basic.6y
#   4973   no  entrepreneur  basic.6y
#   4998   no  entrepreneur  basic.6y
#   5299   no  entrepreneur  basic.6y
#   6363   no  entrepreneur  basic.6y
#   7352   no  entrepreneur  basic.6y
#   7692   no  entrepreneur  basic.6y
#   8002   no  entrepreneur  basic.6y
#   9012   no  entrepreneur  basic.6y
#   9262   no  entrepreneur  basic.6y
#   9514   no  entrepreneur  basic.6y
#   10563  no  entrepreneur  basic.6y
#   10630  no  entrepreneur  basic.6y
#   11031  no  entrepreneur  basic.6y
#   11142  no  entrepreneur  basic.6y
#   11305  no  entrepreneur  basic.6y
#   13204  no  entrepreneur  basic.6y
#   13773  no  entrepreneur  basic.6y
#   13977  no  entrepreneur  basic.6y
#   15366  no  entrepreneur  basic.6y
#   15511  no  entrepreneur  basic.6y
#   15553  no  entrepreneur  basic.6y
#   17483  no  entrepreneur  basic.6y
#   22398  no  entrepreneur  basic.6y
#   22908  no  entrepreneur  basic.6y
#   23369  no  entrepreneur  basic.6y
#   24398  no  entrepreneur  basic.6y
#   27462  no  entrepreneur  basic.6y
#   27802  no  entrepreneur  basic.6y
#   27939  no  entrepreneur  basic.6y
#   28042  no  entrepreneur  basic.6y
#   28362  no  entrepreneur  basic.6y
#   28442  no  entrepreneur  basic.6y
#   28713  no  entrepreneur  basic.6y
#   28765  no  entrepreneur  basic.6y
#   28999  no  entrepreneur  basic.6y
#   29297  no  entrepreneur  basic.6y
#   29622  no  entrepreneur  basic.6y
#   29752  no  entrepreneur  basic.6y
#   31027  no  entrepreneur  basic.6y
#   32372  no  entrepreneur  basic.6y
#   33849  no  entrepreneur  basic.6y
#   34138  no  entrepreneur  basic.6y
#   36004  no  entrepreneur  basic.6y),
#  (('no', 'basic.6y', 'housemaid'),
#           y        job education
#   97     no  housemaid  basic.6y
#   343    no  housemaid  basic.6y
#   629    no  housemaid  basic.6y
#   892    no  housemaid  basic.6y
#   1039   no  housemaid  basic.6y
#   ...    ..        ...       ...
#   28183  no  housemaid  basic.6y
#   28284  no  housemaid  basic.6y
#   28307  no  housemaid  basic.6y
#   30133  no  housemaid  basic.6y
#   30226  no  housemaid  basic.6y
#
#   [64 rows x 3 columns]),
#  (('no', 'basic.6y', 'management'),
#           y         job education
#   63     no  management  basic.6y
#   78     no  management  basic.6y
#   380    no  management  basic.6y
#   416    no  management  basic.6y
#   431    no  management  basic.6y
#   ...    ..         ...       ...
#   30700  no  management  basic.6y
#   31565  no  management  basic.6y
#   31567  no  management  basic.6y
#   32720  no  management  basic.6y
#   34172  no  management  basic.6y
#
#   [66 rows x 3 columns]),
#  (('no', 'basic.6y', 'retired'),
#           y      job education
#   1265   no  retired  basic.6y
#   2178   no  retired  basic.6y
#   3131   no  retired  basic.6y
#   5163   no  retired  basic.6y
#   5982   no  retired  basic.6y
#   ...    ..      ...       ...
#   33773  no  retired  basic.6y
#   34379  no  retired  basic.6y
#   34727  no  retired  basic.6y
#   34745  no  retired  basic.6y
#   36216  no  retired  basic.6y
#
#   [62 rows x 3 columns]),
#  (('no', 'basic.6y', 'self-employed'),
#           y            job education
#   1242   no  self-employed  basic.6y
#   2585   no  self-employed  basic.6y
#   3446   no  self-employed  basic.6y
#   4001   no  self-employed  basic.6y
#   5531   no  self-employed  basic.6y
#   5746   no  self-employed  basic.6y
#   6451   no  self-employed  basic.6y
#   6657   no  self-employed  basic.6y
#   10268  no  self-employed  basic.6y
#   10871  no  self-employed  basic.6y
#   13051  no  self-employed  basic.6y
#   15412  no  self-employed  basic.6y
#   18597  no  self-employed  basic.6y
#   19002  no  self-employed  basic.6y
#   19911  no  self-employed  basic.6y
#   19913  no  self-employed  basic.6y
#   21217  no  self-employed  basic.6y
#   21262  no  self-employed  basic.6y
#   21264  no  self-employed  basic.6y
#   22580  no  self-employed  basic.6y
#   22923  no  self-employed  basic.6y
#   23220  no  self-employed  basic.6y
#   26282  no  self-employed  basic.6y),
#  (('no', 'basic.6y', 'services'),
#           y       job education
#   183    no  services  basic.6y
#   202    no  services  basic.6y
#   230    no  services  basic.6y
#   291    no  services  basic.6y
#   361    no  services  basic.6y
#   ...    ..       ...       ...
#   33457  no  services  basic.6y
#   33466  no  services  basic.6y
#   34341  no  services  basic.6y
#   34343  no  services  basic.6y
#   36126  no  services  basic.6y
#
#   [181 rows x 3 columns]),
#  (('no', 'basic.6y', 'student'),
#           y      job education
#   12271  no  student  basic.6y
#   32534  no  student  basic.6y
#   32654  no  student  basic.6y
#   33889  no  student  basic.6y
#   34654  no  student  basic.6y
#   34655  no  student  basic.6y),
#  (('no', 'basic.6y', 'technician'),
#           y         job education
#   169    no  technician  basic.6y
#   334    no  technician  basic.6y
#   547    no  technician  basic.6y
#   695    no  technician  basic.6y
#   718    no  technician  basic.6y
#   ...    ..         ...       ...
#   32066  no  technician  basic.6y
#   32607  no  technician  basic.6y
#   33610  no  technician  basic.6y
#   34356  no  technician  basic.6y
#   36587  no  technician  basic.6y
#
#   [75 rows x 3 columns]),
#  (('no', 'basic.6y', 'unemployed'),
#           y         job education
#   3605   no  unemployed  basic.6y
#   5125   no  unemployed  basic.6y
#   6996   no  unemployed  basic.6y
#   7357   no  unemployed  basic.6y
#   7523   no  unemployed  basic.6y
#   8183   no  unemployed  basic.6y
#   8695   no  unemployed  basic.6y
#   11881  no  unemployed  basic.6y
#   11882  no  unemployed  basic.6y
#   12095  no  unemployed  basic.6y
#   13337  no  unemployed  basic.6y
#   13453  no  unemployed  basic.6y
#   15261  no  unemployed  basic.6y
#   15752  no  unemployed  basic.6y
#   22355  no  unemployed  basic.6y
#   22357  no  unemployed  basic.6y
#   22430  no  unemployed  basic.6y
#   22668  no  unemployed  basic.6y
#   23617  no  unemployed  basic.6y
#   23718  no  unemployed  basic.6y
#   26658  no  unemployed  basic.6y
#   28746  no  unemployed  basic.6y
#   30787  no  unemployed  basic.6y
#   32954  no  unemployed  basic.6y
#   34145  no  unemployed  basic.6y),
#  (('no', 'basic.6y', 'unknown'),
#           y      job education
#   1051   no  unknown  basic.6y
#   2113   no  unknown  basic.6y
#   2923   no  unknown  basic.6y
#   2948   no  unknown  basic.6y
#   3585   no  unknown  basic.6y
#   4392   no  unknown  basic.6y
#   4501   no  unknown  basic.6y
#   5120   no  unknown  basic.6y
#   5192   no  unknown  basic.6y
#   5445   no  unknown  basic.6y
#   6936   no  unknown  basic.6y
#   7342   no  unknown  basic.6y
#   7679   no  unknown  basic.6y
#   8320   no  unknown  basic.6y
#   8615   no  unknown  basic.6y
#   8858   no  unknown  basic.6y
#   9976   no  unknown  basic.6y
#   14682  no  unknown  basic.6y
#   14831  no  unknown  basic.6y
#   18667  no  unknown  basic.6y
#   33310  no  unknown  basic.6y),
#  (('no', 'basic.9y', 'admin.'),
#           y     job education
#   61     no  admin.  basic.9y
#   180    no  admin.  basic.9y
#   238    no  admin.  basic.9y
#   254    no  admin.  basic.9y
#   284    no  admin.  basic.9y
#   ...    ..     ...       ...
#   35792  no  admin.  basic.9y
#   36482  no  admin.  basic.9y
#   36547  no  admin.  basic.9y
#   36564  no  admin.  basic.9y
#   36916  no  admin.  basic.9y
#
#   [421 rows x 3 columns]),
#  (('no', 'basic.9y', 'blue-collar'),
#           y          job education
#   14     no  blue-collar  basic.9y
#   40     no  blue-collar  basic.9y
#   42     no  blue-collar  basic.9y
#   54     no  blue-collar  basic.9y
#   59     no  blue-collar  basic.9y
#   ...    ..          ...       ...
#   36654  no  blue-collar  basic.9y
#   36851  no  blue-collar  basic.9y
#   36853  no  blue-collar  basic.9y
#   36978  no  blue-collar  basic.9y
#   37048  no  blue-collar  basic.9y
#
#   [3020 rows x 3 columns]),
#  (('no', 'basic.9y', 'entrepreneur'),
#           y           job education
#   626    no  entrepreneur  basic.9y
#   708    no  entrepreneur  basic.9y
#   743    no  entrepreneur  basic.9y
#   754    no  entrepreneur  basic.9y
#   824    no  entrepreneur  basic.9y
#   ...    ..           ...       ...
#   31848  no  entrepreneur  basic.9y
#   32486  no  entrepreneur  basic.9y
#   33025  no  entrepreneur  basic.9y
#   34477  no  entrepreneur  basic.9y
#   35491  no  entrepreneur  basic.9y
#
#   [186 rows x 3 columns]),
#  (('no', 'basic.9y', 'housemaid'),
#           y        job education
#   245    no  housemaid  basic.9y
#   388    no  housemaid  basic.9y
#   690    no  housemaid  basic.9y
#   854    no  housemaid  basic.9y
#   1145   no  housemaid  basic.9y
#   ...    ..        ...       ...
#   30811  no  housemaid  basic.9y
#   31922  no  housemaid  basic.9y
#   31964  no  housemaid  basic.9y
#   32147  no  housemaid  basic.9y
#   35559  no  housemaid  basic.9y
#
#   [79 rows x 3 columns]),
#  (('no', 'basic.9y', 'management'),
#           y         job education
#   15     no  management  basic.9y
#   159    no  management  basic.9y
#   288    no  management  basic.9y
#   853    no  management  basic.9y
#   1517   no  management  basic.9y
#   ...    ..         ...       ...
#   33819  no  management  basic.9y
#   34633  no  management  basic.9y
#   35152  no  management  basic.9y
#   35651  no  management  basic.9y
#   35745  no  management  basic.9y
#
#   [148 rows x 3 columns]),
#  (('no', 'basic.9y', 'retired'),
#           y      job education
#   11     no  retired  basic.9y
#   820    no  retired  basic.9y
#   1012   no  retired  basic.9y
#   2348   no  retired  basic.9y
#   2488   no  retired  basic.9y
#   ...    ..      ...       ...
#   35631  no  retired  basic.9y
#   35632  no  retired  basic.9y
#   35765  no  retired  basic.9y
#   35779  no  retired  basic.9y
#   36566  no  retired  basic.9y
#
#   [110 rows x 3 columns]),
#  (('no', 'basic.9y', 'self-employed'),
#           y            job education
#   370    no  self-employed  basic.9y
#   385    no  self-employed  basic.9y
#   628    no  self-employed  basic.9y
#   630    no  self-employed  basic.9y
#   872    no  self-employed  basic.9y
#   ...    ..            ...       ...
#   31797  no  self-employed  basic.9y
#   31808  no  self-employed  basic.9y
#   33254  no  self-employed  basic.9y
#   34866  no  self-employed  basic.9y
#   36796  no  self-employed  basic.9y
#
#   [182 rows x 3 columns]),
#  (('no', 'basic.9y', 'services'),
#           y       job education
#   1      no  services  basic.9y
#   222    no  services  basic.9y
#   671    no  services  basic.9y
#   1103   no  services  basic.9y
#   1147   no  services  basic.9y
#   ...    ..       ...       ...
#   35754  no  services  basic.9y
#   35958  no  services  basic.9y
#   36152  no  services  basic.9y
#   36327  no  services  basic.9y
#   36965  no  services  basic.9y
#
#   [312 rows x 3 columns]),
#  (('no', 'basic.9y', 'student'),
#           y      job education
#   403    no  student  basic.9y
#   3141   no  student  basic.9y
#   3576   no  student  basic.9y
#   5479   no  student  basic.9y
#   7436   no  student  basic.9y
#   9064   no  student  basic.9y
#   10017  no  student  basic.9y
#   12479  no  student  basic.9y
#   13468  no  student  basic.9y
#   14234  no  student  basic.9y
#   23832  no  student  basic.9y
#   24938  no  student  basic.9y
#   24939  no  student  basic.9y
#   24941  no  student  basic.9y
#   24952  no  student  basic.9y
#   24959  no  student  basic.9y
#   25130  no  student  basic.9y
#   25135  no  student  basic.9y
#   25373  no  student  basic.9y
#   25882  no  student  basic.9y
#   28015  no  student  basic.9y
#   28291  no  student  basic.9y
#   28384  no  student  basic.9y
#   28645  no  student  basic.9y
#   28822  no  student  basic.9y
#   29080  no  student  basic.9y
#   29186  no  student  basic.9y
#   31028  no  student  basic.9y
#   31224  no  student  basic.9y
#   32308  no  student  basic.9y
#   32387  no  student  basic.9y
#   32616  no  student  basic.9y
#   33414  no  student  basic.9y
#   33577  no  student  basic.9y
#   33591  no  student  basic.9y
#   33593  no  student  basic.9y
#   33674  no  student  basic.9y
#   33812  no  student  basic.9y
#   33827  no  student  basic.9y
#   33857  no  student  basic.9y
#   33943  no  student  basic.9y
#   34140  no  student  basic.9y
#   34441  no  student  basic.9y
#   34455  no  student  basic.9y
#   34751  no  student  basic.9y
#   35135  no  student  basic.9y
#   35138  no  student  basic.9y
#   35182  no  student  basic.9y
#   35281  no  student  basic.9y
#   35581  no  student  basic.9y
#   35582  no  student  basic.9y
#   35636  no  student  basic.9y
#   36067  no  student  basic.9y
#   36115  no  student  basic.9y
#   36219  no  student  basic.9y
#   36355  no  student  basic.9y
#   36361  no  student  basic.9y
#   36499  no  student  basic.9y
#   36649  no  student  basic.9y
#   36995  no  student  basic.9y),
#  (('no', 'basic.9y', 'technician'),
#           y         job education
#   30     no  technician  basic.9y
#   204    no  technician  basic.9y
#   529    no  technician  basic.9y
#   578    no  technician  basic.9y
#   595    no  technician  basic.9y
#   ...    ..         ...       ...
#   34435  no  technician  basic.9y
#   34817  no  technician  basic.9y
#   36228  no  technician  basic.9y
#   36477  no  technician  basic.9y
#   37004  no  technician  basic.9y
#
#   [308 rows x 3 columns]),
#  (('no', 'basic.9y', 'unemployed'),
#           y         job education
#   84     no  unemployed  basic.9y
#   436    no  unemployed  basic.9y
#   632    no  unemployed  basic.9y
#   1048   no  unemployed  basic.9y
#   1266   no  unemployed  basic.9y
#   ...    ..         ...       ...
#   33818  no  unemployed  basic.9y
#   34447  no  unemployed  basic.9y
#   36498  no  unemployed  basic.9y
#   36792  no  unemployed  basic.9y
#   36812  no  unemployed  basic.9y
#
#   [147 rows x 3 columns]),
#  (('no', 'basic.9y', 'unknown'),
#           y      job education
#   787    no  unknown  basic.9y
#   1073   no  unknown  basic.9y
#   1075   no  unknown  basic.9y
#   1131   no  unknown  basic.9y
#   1227   no  unknown  basic.9y
#   1707   no  unknown  basic.9y
#   2535   no  unknown  basic.9y
#   2583   no  unknown  basic.9y
#   4334   no  unknown  basic.9y
#   4903   no  unknown  basic.9y
#   5555   no  unknown  basic.9y
#   6481   no  unknown  basic.9y
#   7222   no  unknown  basic.9y
#   9379   no  unknown  basic.9y
#   11377  no  unknown  basic.9y
#   12726  no  unknown  basic.9y
#   12739  no  unknown  basic.9y
#   12765  no  unknown  basic.9y
#   16995  no  unknown  basic.9y
#   17103  no  unknown  basic.9y
#   17179  no  unknown  basic.9y
#   18964  no  unknown  basic.9y
#   19307  no  unknown  basic.9y
#   21815  no  unknown  basic.9y
#   24967  no  unknown  basic.9y
#   32391  no  unknown  basic.9y
#   35026  no  unknown  basic.9y
#   36205  no  unknown  basic.9y),
#  (('no', 'high.school', 'admin.'),
#           y     job    education
#   19     no  admin.  high.school
#   43     no  admin.  high.school
#   45     no  admin.  high.school
#   57     no  admin.  high.school
#   74     no  admin.  high.school
#   ...    ..     ...          ...
#   37005  no  admin.  high.school
#   37006  no  admin.  high.school
#   37007  no  admin.  high.school
#   37011  no  admin.  high.school
#   37027  no  admin.  high.school
#
#   [2657 rows x 3 columns]),
#  (('no', 'high.school', 'blue-collar'),
#           y          job    education
#   8      no  blue-collar  high.school
#   106    no  blue-collar  high.school
#   111    no  blue-collar  high.school
#   112    no  blue-collar  high.school
#   267    no  blue-collar  high.school
#   ...    ..          ...          ...
#   36114  no  blue-collar  high.school
#   36157  no  blue-collar  high.school
#   36208  no  blue-collar  high.school
#   36502  no  blue-collar  high.school
#   36588  no  blue-collar  high.school
#
#   [695 rows x 3 columns]),
#  (('no', 'high.school', 'entrepreneur'),
#           y           job    education
#   34     no  entrepreneur  high.school
#   301    no  entrepreneur  high.school
#   453    no  entrepreneur  high.school
#   454    no  entrepreneur  high.school
#   979    no  entrepreneur  high.school
#   ...    ..           ...          ...
#   34793  no  entrepreneur  high.school
#   34794  no  entrepreneur  high.school
#   35859  no  entrepreneur  high.school
#   36574  no  entrepreneur  high.school
#   36576  no  entrepreneur  high.school
#
#   [192 rows x 3 columns]),
#  (('no', 'high.school', 'housemaid'),
#           y        job    education
#   247    no  housemaid  high.school
#   580    no  housemaid  high.school
#   581    no  housemaid  high.school
#   1088   no  housemaid  high.school
#   1090   no  housemaid  high.school
#   ...    ..        ...          ...
#   33522  no  housemaid  high.school
#   34348  no  housemaid  high.school
#   35969  no  housemaid  high.school
#   36190  no  housemaid  high.school
#   37074  no  housemaid  high.school
#
#   [142 rows x 3 columns]),
#  (('no', 'high.school', 'management'),
#           y         job    education
#   299    no  management  high.school
#   330    no  management  high.school
#   347    no  management  high.school
#   707    no  management  high.school
#   731    no  management  high.school
#   ...    ..         ...          ...
#   34895  no  management  high.school
#   35819  no  management  high.school
#   35959  no  management  high.school
#   36288  no  management  high.school
#   36486  no  management  high.school
#
#   [248 rows x 3 columns]),
#  (('no', 'high.school', 'retired'),
#           y      job    education
#   17     no  retired  high.school
#   170    no  retired  high.school
#   219    no  retired  high.school
#   573    no  retired  high.school
#   620    no  retired  high.school
#   ...    ..      ...          ...
#   36523  no  retired  high.school
#   36536  no  retired  high.school
#   36549  no  retired  high.school
#   36893  no  retired  high.school
#   36927  no  retired  high.school
#
#   [196 rows x 3 columns]),
#  (('no', 'high.school', 'self-employed'),
#           y            job    education
#   327    no  self-employed  high.school
#   481    no  self-employed  high.school
#   723    no  self-employed  high.school
#   900    no  self-employed  high.school
#   1031   no  self-employed  high.school
#   ...    ..            ...          ...
#   32185  no  self-employed  high.school
#   33429  no  self-employed  high.school
#   34309  no  self-employed  high.school
#   34488  no  self-employed  high.school
#   34975  no  self-employed  high.school
#
#   [99 rows x 3 columns]),
#  (('no', 'high.school', 'services'),
#           y       job    education
#   0      no  services  high.school
#   5      no  services  high.school
#   7      no  services  high.school
#   29     no  services  high.school
#   50     no  services  high.school
#   ...    ..       ...          ...
#   36974  no  services  high.school
#   36983  no  services  high.school
#   36997  no  services  high.school
#   37037  no  services  high.school
#   37067  no  services  high.school
#
#   [2214 rows x 3 columns]),
#  (('no', 'high.school', 'student'),
#           y      job    education
#   1101   no  student  high.school
#   1137   no  student  high.school
#   1741   no  student  high.school
#   1831   no  student  high.school
#   2383   no  student  high.school
#   ...    ..      ...          ...
#   36923  no  student  high.school
#   36942  no  student  high.school
#   36955  no  student  high.school
#   36957  no  student  high.school
#   36984  no  student  high.school
#
#   [206 rows x 3 columns]),
#  (('no', 'high.school', 'technician'),
#           y         job    education
#   18     no  technician  high.school
#   114    no  technician  high.school
#   164    no  technician  high.school
#   226    no  technician  high.school
#   237    no  technician  high.school
#   ...    ..         ...          ...
#   35814  no  technician  high.school
#   35866  no  technician  high.school
#   36020  no  technician  high.school
#   36752  no  technician  high.school
#   36906  no  technician  high.school
#
#   [721 rows x 3 columns]),
#  (('no', 'high.school', 'unemployed'),
#           y         job    education
#   244    no  unemployed  high.school
#   322    no  unemployed  high.school
#   1085   no  unemployed  high.school
#   1160   no  unemployed  high.school
#   1427   no  unemployed  high.school
#   ...    ..         ...          ...
#   36304  no  unemployed  high.school
#   36421  no  unemployed  high.school
#   36558  no  unemployed  high.school
#   36563  no  unemployed  high.school
#   36667  no  unemployed  high.school
#
#   [198 rows x 3 columns]),
#  (('no', 'high.school', 'unknown'),
#           y      job    education
#   134    no  unknown  high.school
#   1004   no  unknown  high.school
#   2471   no  unknown  high.school
#   2801   no  unknown  high.school
#   2832   no  unknown  high.school
#   2912   no  unknown  high.school
#   4363   no  unknown  high.school
#   5314   no  unknown  high.school
#   5486   no  unknown  high.school
#   5499   no  unknown  high.school
#   5794   no  unknown  high.school
#   6217   no  unknown  high.school
#   7020   no  unknown  high.school
#   7163   no  unknown  high.school
#   9346   no  unknown  high.school
#   13742  no  unknown  high.school
#   16168  no  unknown  high.school
#   16251  no  unknown  high.school
#   16434  no  unknown  high.school
#   16737  no  unknown  high.school
#   19188  no  unknown  high.school
#   19251  no  unknown  high.school
#   19432  no  unknown  high.school
#   20786  no  unknown  high.school
#   29532  no  unknown  high.school
#   29662  no  unknown  high.school
#   34616  no  unknown  high.school
#   35812  no  unknown  high.school
#   35818  no  unknown  high.school),
#  (('no', 'illiterate', 'admin.'),
#           y     job   education
#   11169  no  admin.  illiterate),
#  (('no', 'illiterate', 'blue-collar'),
#           y          job   education
#   4852   no  blue-collar  illiterate
#   6262   no  blue-collar  illiterate
#   13038  no  blue-collar  illiterate
#   13075  no  blue-collar  illiterate
#   15957  no  blue-collar  illiterate
#   20163  no  blue-collar  illiterate
#   20381  no  blue-collar  illiterate
#   31824  no  blue-collar  illiterate),
#  (('no', 'illiterate', 'entrepreneur'),
#           y           job   education
#   25785  no  entrepreneur  illiterate),
#  (('no', 'illiterate', 'housemaid'),
#           y        job   education
#   14651  no  housemaid  illiterate),
#  (('no', 'illiterate', 'retired'),
#           y      job   education
#   34067  no  retired  illiterate),
#  (('no', 'illiterate', 'self-employed'),
#           y            job   education
#   24027  no  self-employed  illiterate
#   24094  no  self-employed  illiterate),
#  (('no', 'professional.course', 'admin.'),
#           y     job            education
#   2      no  admin.  professional.course
#   35     no  admin.  professional.course
#   46     no  admin.  professional.course
#   209    no  admin.  professional.course
#   214    no  admin.  professional.course
#   ...    ..     ...                  ...
#   35518  no  admin.  professional.course
#   36261  no  admin.  professional.course
#   36318  no  admin.  professional.course
#   36495  no  admin.  professional.course
#   37042  no  admin.  professional.course
#
#   [284 rows x 3 columns]),
#  (('no', 'professional.course', 'blue-collar'),
#           y          job            education
#   194    no  blue-collar  professional.course
#   282    no  blue-collar  professional.course
#   389    no  blue-collar  professional.course
#   656    no  blue-collar  professional.course
#   673    no  blue-collar  professional.course
#   ...    ..          ...                  ...
#   36099  no  blue-collar  professional.course
#   36497  no  blue-collar  professional.course
#   36989  no  blue-collar  professional.course
#   36990  no  blue-collar  professional.course
#   37080  no  blue-collar  professional.course
#
#   [374 rows x 3 columns]),
#  (('no', 'professional.course', 'entrepreneur'),
#           y           job            education
#   505    no  entrepreneur  professional.course
#   608    no  entrepreneur  professional.course
#   715    no  entrepreneur  professional.course
#   2054   no  entrepreneur  professional.course
#   2330   no  entrepreneur  professional.course
#   ...    ..           ...                  ...
#   34554  no  entrepreneur  professional.course
#   34557  no  entrepreneur  professional.course
#   35676  no  entrepreneur  professional.course
#   36391  no  entrepreneur  professional.course
#   36483  no  entrepreneur  professional.course
#
#   [112 rows x 3 columns]),
#  (('no', 'professional.course', 'housemaid'),
#           y        job            education
#   293    no  housemaid  professional.course
#   434    no  housemaid  professional.course
#   4030   no  housemaid  professional.course
#   4647   no  housemaid  professional.course
#   4931   no  housemaid  professional.course
#   5013   no  housemaid  professional.course
#   7007   no  housemaid  professional.course
#   7250   no  housemaid  professional.course
#   7316   no  housemaid  professional.course
#   8021   no  housemaid  professional.course
#   8192   no  housemaid  professional.course
#   8772   no  housemaid  professional.course
#   9361   no  housemaid  professional.course
#   9907   no  housemaid  professional.course
#   10082  no  housemaid  professional.course
#   12343  no  housemaid  professional.course
#   12389  no  housemaid  professional.course
#   15937  no  housemaid  professional.course
#   15999  no  housemaid  professional.course
#   16473  no  housemaid  professional.course
#   17215  no  housemaid  professional.course
#   18340  no  housemaid  professional.course
#   18950  no  housemaid  professional.course
#   18956  no  housemaid  professional.course
#   18998  no  housemaid  professional.course
#   19109  no  housemaid  professional.course
#   19984  no  housemaid  professional.course
#   19985  no  housemaid  professional.course
#   20069  no  housemaid  professional.course
#   20194  no  housemaid  professional.course
#   20197  no  housemaid  professional.course
#   20262  no  housemaid  professional.course
#   22362  no  housemaid  professional.course
#   22417  no  housemaid  professional.course
#   23043  no  housemaid  professional.course
#   32462  no  housemaid  professional.course
#   33238  no  housemaid  professional.course
#   34048  no  housemaid  professional.course
#   34559  no  housemaid  professional.course
#   34562  no  housemaid  professional.course
#   35490  no  housemaid  professional.course
#   35492  no  housemaid  professional.course
#   35498  no  housemaid  professional.course),
#  (('no', 'professional.course', 'management'),
#           y         job            education
#   306    no  management  professional.course
#   407    no  management  professional.course
#   417    no  management  professional.course
#   613    no  management  professional.course
#   1518   no  management  professional.course
#   ...    ..         ...                  ...
#   32140  no  management  professional.course
#   33266  no  management  professional.course
#   34672  no  management  professional.course
#   35108  no  management  professional.course
#   36672  no  management  professional.course
#
#   [74 rows x 3 columns]),
#  (('no', 'professional.course', 'retired'),
#           y      job            education
#   251    no  retired  professional.course
#   271    no  retired  professional.course
#   1934   no  retired  professional.course
#   2166   no  retired  professional.course
#   2189   no  retired  professional.course
#   ...    ..      ...                  ...
#   36848  no  retired  professional.course
#   36963  no  retired  professional.course
#   37075  no  retired  professional.course
#   37077  no  retired  professional.course
#   37083  no  retired  professional.course
#
#   [163 rows x 3 columns]),
#  (('no', 'professional.course', 'self-employed'),
#           y            job            education
#   266    no  self-employed  professional.course
#   992    no  self-employed  professional.course
#   1268   no  self-employed  professional.course
#   1272   no  self-employed  professional.course
#   1425   no  self-employed  professional.course
#   ...    ..            ...                  ...
#   32984  no  self-employed  professional.course
#   34510  no  self-employed  professional.course
#   34519  no  self-employed  professional.course
#   35952  no  self-employed  professional.course
#   36494  no  self-employed  professional.course
#
#   [140 rows x 3 columns]),
#  (('no', 'professional.course', 'services'),
#           y       job            education
#   86     no  services  professional.course
#   210    no  services  professional.course
#   311    no  services  professional.course
#   386    no  services  professional.course
#   924    no  services  professional.course
#   ...    ..       ...                  ...
#   33216  no  services  professional.course
#   35334  no  services  professional.course
#   36557  no  services  professional.course
#   36653  no  services  professional.course
#   36737  no  services  professional.course
#
#   [180 rows x 3 columns]),
#  (('no', 'professional.course', 'student'),
#           y      job            education
#   10392  no  student  professional.course
#   16966  no  student  professional.course
#   17654  no  student  professional.course
#   21703  no  student  professional.course
#   24372  no  student  professional.course
#   24579  no  student  professional.course
#   26327  no  student  professional.course
#   26406  no  student  professional.course
#   32552  no  student  professional.course
#   33063  no  student  professional.course
#   33594  no  student  professional.course
#   34095  no  student  professional.course
#   34913  no  student  professional.course
#   35035  no  student  professional.course
#   36153  no  student  professional.course
#   36770  no  student  professional.course
#   36773  no  student  professional.course
#   36774  no  student  professional.course
#   36775  no  student  professional.course
#   36780  no  student  professional.course
#   36889  no  student  professional.course),
#  (('no', 'professional.course', 'technician'),
#           y         job            education
#   4      no  technician  professional.course
#   38     no  technician  professional.course
#   48     no  technician  professional.course
#   89     no  technician  professional.course
#   118    no  technician  professional.course
#   ...    ..         ...                  ...
#   36845  no  technician  professional.course
#   36852  no  technician  professional.course
#   36875  no  technician  professional.course
#   37041  no  technician  professional.course
#   37052  no  technician  professional.course
#
#   [2688 rows x 3 columns]),
#  (('no', 'professional.course', 'unemployed'),
#           y         job            education
#   51     no  unemployed  professional.course
#   188    no  unemployed  professional.course
#   868    no  unemployed  professional.course
#   885    no  unemployed  professional.course
#   1151   no  unemployed  professional.course
#   ...    ..         ...                  ...
#   35193  no  unemployed  professional.course
#   35607  no  unemployed  professional.course
#   35970  no  unemployed  professional.course
#   36937  no  unemployed  professional.course
#   37034  no  unemployed  professional.course
#
#   [116 rows x 3 columns]),
#  (('no', 'professional.course', 'unknown'),
#           y      job            education
#   12344  no  unknown  professional.course
#   12380  no  unknown  professional.course
#   19890  no  unknown  professional.course
#   27438  no  unknown  professional.course
#   32721  no  unknown  professional.course
#   32751  no  unknown  professional.course
#   32764  no  unknown  professional.course
#   32947  no  unknown  professional.course
#   32981  no  unknown  professional.course
#   36920  no  unknown  professional.course),
#  (('no', 'university.degree', 'admin.'),
#           y     job          education
#   31     no  admin.  university.degree
#   36     no  admin.  university.degree
#   37     no  admin.  university.degree
#   39     no  admin.  university.degree
#   41     no  admin.  university.degree
#   ...    ..     ...                ...
#   37019  no  admin.  university.degree
#   37035  no  admin.  university.degree
#   37047  no  admin.  university.degree
#   37059  no  admin.  university.degree
#   37065  no  admin.  university.degree
#
#   [4432 rows x 3 columns]),
#  (('no', 'university.degree', 'blue-collar'),
#           y          job          education
#   1434   no  blue-collar  university.degree
#   2099   no  blue-collar  university.degree
#   2104   no  blue-collar  university.degree
#   2313   no  blue-collar  university.degree
#   2407   no  blue-collar  university.degree
#   ...    ..          ...                ...
#   33671  no  blue-collar  university.degree
#   34648  no  blue-collar  university.degree
#   35870  no  blue-collar  university.degree
#   36037  no  blue-collar  university.degree
#   36730  no  blue-collar  university.degree
#
#   [81 rows x 3 columns]),
#  (('no', 'university.degree', 'entrepreneur'),
#           y           job          education
#   53     no  entrepreneur  university.degree
#   313    no  entrepreneur  university.degree
#   360    no  entrepreneur  university.degree
#   442    no  entrepreneur  university.degree
#   447    no  entrepreneur  university.degree
#   ...    ..           ...                ...
#   35927  no  entrepreneur  university.degree
#   36068  no  entrepreneur  university.degree
#   36097  no  entrepreneur  university.degree
#   36602  no  entrepreneur  university.degree
#   37066  no  entrepreneur  university.degree
#
#   [488 rows x 3 columns]),
#  (('no', 'university.degree', 'housemaid'),
#           y        job          education
#   191    no  housemaid  university.degree
#   393    no  housemaid  university.degree
#   576    no  housemaid  university.degree
#   1263   no  housemaid  university.degree
#   1405   no  housemaid  university.degree
#   ...    ..        ...                ...
#   35639  no  housemaid  university.degree
#   36418  no  housemaid  university.degree
#   36742  no  housemaid  university.degree
#   37053  no  housemaid  university.degree
#   37055  no  housemaid  university.degree
#
#   [110 rows x 3 columns]),
#  (('no', 'university.degree', 'management'),
#           y         job          education
#   33     no  management  university.degree
#   49     no  management  university.degree
#   64     no  management  university.degree
#   87     no  management  university.degree
#   105    no  management  university.degree
#   ...    ..         ...                ...
#   36790  no  management  university.degree
#   36941  no  management  university.degree
#   37029  no  management  university.degree
#   37050  no  management  university.degree
#   37068  no  management  university.degree
#
#   [1629 rows x 3 columns]),
#  (('no', 'university.degree', 'retired'),
#           y      job          education
#   101    no  retired  university.degree
#   205    no  retired  university.degree
#   346    no  retired  university.degree
#   489    no  retired  university.degree
#   637    no  retired  university.degree
#   ...    ..      ...                ...
#   36843  no  retired  university.degree
#   36888  no  retired  university.degree
#   36905  no  retired  university.degree
#   36976  no  retired  university.degree
#   37081  no  retired  university.degree
#
#   [192 rows x 3 columns]),
#  (('no', 'university.degree', 'self-employed'),
#           y            job          education
#   213    no  self-employed  university.degree
#   241    no  self-employed  university.degree
#   300    no  self-employed  university.degree
#   342    no  self-employed  university.degree
#   354    no  self-employed  university.degree
#   ...    ..            ...                ...
#   36878  no  self-employed  university.degree
#   36883  no  self-employed  university.degree
#   36885  no  self-employed  university.degree
#   36936  no  self-employed  university.degree
#   37031  no  self-employed  university.degree
#
#   [593 rows x 3 columns]),
#  (('no', 'university.degree', 'services'),
#           y       job          education
#   676    no  services  university.degree
#   740    no  services  university.degree
#   1159   no  services  university.degree
#   1492   no  services  university.degree
#   3351   no  services  university.degree
#   ...    ..       ...                ...
#   36544  no  services  university.degree
#   36586  no  services  university.degree
#   36827  no  services  university.degree
#   36835  no  services  university.degree
#   36840  no  services  university.degree
#
#   [136 rows x 3 columns]),
#  (('no', 'university.degree', 'student'),
#           y      job          education
#   186    no  student  university.degree
#   187    no  student  university.degree
#   190    no  student  university.degree
#   242    no  student  university.degree
#   640    no  student  university.degree
#   ...    ..      ...                ...
#   36500  no  student  university.degree
#   36569  no  student  university.degree
#   36758  no  student  university.degree
#   36795  no  student  university.degree
#   36856  no  student  university.degree
#
#   [123 rows x 3 columns]),
#  (('no', 'university.degree', 'technician'),
#           y         job          education
#   20     no  technician  university.degree
#   22     no  technician  university.degree
#   52     no  technician  university.degree
#   69     no  technician  university.degree
#   76     no  technician  university.degree
#   ...    ..         ...                ...
#   36947  no  technician  university.degree
#   36959  no  technician  university.degree
#   36969  no  technician  university.degree
#   36971  no  technician  university.degree
#   36994  no  technician  university.degree
#
#   [1443 rows x 3 columns]),
#  (('no', 'university.degree', 'unemployed'),
#           y         job          education
#   130    no  unemployed  university.degree
#   318    no  unemployed  university.degree
#   358    no  unemployed  university.degree
#   1093   no  unemployed  university.degree
#   1186   no  unemployed  university.degree
#   ...    ..         ...                ...
#   35972  no  unemployed  university.degree
#   36100  no  unemployed  university.degree
#   36570  no  unemployed  university.degree
#   36579  no  unemployed  university.degree
#   36846  no  unemployed  university.degree
#
#   [205 rows x 3 columns]),
#  (('no', 'university.degree', 'unknown'),
#           y      job          education
#   23     no  unknown  university.degree
#   1657   no  unknown  university.degree
#   2044   no  unknown  university.degree
#   2093   no  unknown  university.degree
#   2387   no  unknown  university.degree
#   2777   no  unknown  university.degree
#   3907   no  unknown  university.degree
#   3923   no  unknown  university.degree
#   5489   no  unknown  university.degree
#   6452   no  unknown  university.degree
#   8583   no  unknown  university.degree
#   10246  no  unknown  university.degree
#   14983  no  unknown  university.degree
#   15596  no  unknown  university.degree
#   17056  no  unknown  university.degree
#   17058  no  unknown  university.degree
#   17084  no  unknown  university.degree
#   17178  no  unknown  university.degree
#   18760  no  unknown  university.degree
#   27599  no  unknown  university.degree
#   32801  no  unknown  university.degree
#   32805  no  unknown  university.degree
#   32946  no  unknown  university.degree
#   33595  no  unknown  university.degree
#   34295  no  unknown  university.degree
#   34353  no  unknown  university.degree
#   34354  no  unknown  university.degree
#   34684  no  unknown  university.degree
#   34688  no  unknown  university.degree
#   35240  no  unknown  university.degree
#   35744  no  unknown  university.degree
#   36017  no  unknown  university.degree),
#  (('no', 'unknown', 'admin.'),
# ...
#   32589  yes  retired  university.degree
#   33473  yes  retired  university.degree
#   33485  yes  retired  university.degree
#   33555  yes  retired  university.degree
#   33684  yes  retired  university.degree
#   33688  yes  retired  university.degree
#   33904  yes  retired  university.degree
#   33948  yes  retired  university.degree
#   33971  yes  retired  university.degree
#   34197  yes  retired  university.degree
#   34330  yes  retired  university.degree
#   34382  yes  retired  university.degree
#   34432  yes  retired  university.degree
#   34530  yes  retired  university.degree
#   34809  yes  retired  university.degree
#   34893  yes  retired  university.degree
#   34900  yes  retired  university.degree
#   34934  yes  retired  university.degree
#   35022  yes  retired  university.degree
#   35039  yes  retired  university.degree
#   35055  yes  retired  university.degree
#   35156  yes  retired  university.degree
#   35159  yes  retired  university.degree
#   35183  yes  retired  university.degree
#   35302  yes  retired  university.degree
#   35513  yes  retired  university.degree
#   35687  yes  retired  university.degree
#   35698  yes  retired  university.degree
#   35736  yes  retired  university.degree
#   36076  yes  retired  university.degree
#   36125  yes  retired  university.degree
#   36127  yes  retired  university.degree
#   36252  yes  retired  university.degree
#   36456  yes  retired  university.degree
#   36512  yes  retired  university.degree
#   37071  yes  retired  university.degree
#   37072  yes  retired  university.degree
#   37076  yes  retired  university.degree),
#  (('yes', 'university.degree', 'self-employed'),
#            y            job          education
#   8361   yes  self-employed  university.degree
#   8890   yes  self-employed  university.degree
#   9669   yes  self-employed  university.degree
#   10875  yes  self-employed  university.degree
#   14988  yes  self-employed  university.degree
#   ...    ...            ...                ...
#   36065  yes  self-employed  university.degree
#   36086  yes  self-employed  university.degree
#   36170  yes  self-employed  university.degree
#   36465  yes  self-employed  university.degree
#   36484  yes  self-employed  university.degree
#
#   [84 rows x 3 columns]),
#  (('yes', 'university.degree', 'services'),
#            y       job          education
#   7201   yes  services  university.degree
#   14258  yes  services  university.degree
#   14531  yes  services  university.degree
#   14558  yes  services  university.degree
#   18464  yes  services  university.degree
#   27241  yes  services  university.degree
#   27828  yes  services  university.degree
#   32413  yes  services  university.degree
#   32504  yes  services  university.degree
#   33331  yes  services  university.degree
#   33528  yes  services  university.degree
#   33529  yes  services  university.degree
#   35106  yes  services  university.degree
#   35296  yes  services  university.degree
#   35340  yes  services  university.degree
#   35341  yes  services  university.degree
#   35737  yes  services  university.degree
#   35801  yes  services  university.degree
#   36413  yes  services  university.degree
#   36468  yes  services  university.degree
#   36611  yes  services  university.degree
#   36841  yes  services  university.degree
#   36847  yes  services  university.degree
#   37013  yes  services  university.degree),
#  (('yes', 'university.degree', 'student'),
#            y      job          education
#   2484   yes  student  university.degree
#   7317   yes  student  university.degree
#   10019  yes  student  university.degree
#   26013  yes  student  university.degree
#   26625  yes  student  university.degree
#   27103  yes  student  university.degree
#   30219  yes  student  university.degree
#   31393  yes  student  university.degree
#   32974  yes  student  university.degree
#   33029  yes  student  university.degree
#   33033  yes  student  university.degree
#   33218  yes  student  university.degree
#   33225  yes  student  university.degree
#   33412  yes  student  university.degree
#   33978  yes  student  university.degree
#   34091  yes  student  university.degree
#   34099  yes  student  university.degree
#   34108  yes  student  university.degree
#   34443  yes  student  university.degree
#   34824  yes  student  university.degree
#   34883  yes  student  university.degree
#   34925  yes  student  university.degree
#   35619  yes  student  university.degree
#   35729  yes  student  university.degree
#   35752  yes  student  university.degree
#   35787  yes  student  university.degree
#   35795  yes  student  university.degree
#   36234  yes  student  university.degree
#   36237  yes  student  university.degree
#   36337  yes  student  university.degree
#   36348  yes  student  university.degree
#   36351  yes  student  university.degree
#   36961  yes  student  university.degree),
#  (('yes', 'university.degree', 'technician'),
#            y         job          education
#   1117   yes  technician  university.degree
#   2158   yes  technician  university.degree
#   2184   yes  technician  university.degree
#   3208   yes  technician  university.degree
#   4279   yes  technician  university.degree
#   ...    ...         ...                ...
#   36801  yes  technician  university.degree
#   36854  yes  technician  university.degree
#   36909  yes  technician  university.degree
#   36962  yes  technician  university.degree
#   36970  yes  technician  university.degree
#
#   [201 rows x 3 columns]),
#  (('yes', 'university.degree', 'unemployed'),
#            y         job          education
#   13636  yes  unemployed  university.degree
#   16290  yes  unemployed  university.degree
#   18050  yes  unemployed  university.degree
#   19727  yes  unemployed  university.degree
#   25654  yes  unemployed  university.degree
#   25655  yes  unemployed  university.degree
#   25685  yes  unemployed  university.degree
#   25703  yes  unemployed  university.degree
#   25735  yes  unemployed  university.degree
#   27040  yes  unemployed  university.degree
#   27286  yes  unemployed  university.degree
#   27454  yes  unemployed  university.degree
#   31716  yes  unemployed  university.degree
#   32647  yes  unemployed  university.degree
#   33108  yes  unemployed  university.degree
#   33132  yes  unemployed  university.degree
#   33742  yes  unemployed  university.degree
#   34597  yes  unemployed  university.degree
#   34598  yes  unemployed  university.degree
#   34813  yes  unemployed  university.degree
#   35201  yes  unemployed  university.degree
#   35310  yes  unemployed  university.degree
#   35363  yes  unemployed  university.degree
#   35365  yes  unemployed  university.degree
#   35368  yes  unemployed  university.degree
#   35481  yes  unemployed  university.degree
#   35977  yes  unemployed  university.degree
#   35994  yes  unemployed  university.degree
#   36009  yes  unemployed  university.degree
#   36133  yes  unemployed  university.degree
#   36218  yes  unemployed  university.degree
#   36369  yes  unemployed  university.degree
#   36371  yes  unemployed  university.degree
#   37036  yes  unemployed  university.degree),
#  (('yes', 'university.degree', 'unknown'),
#            y      job          education
#   1435   yes  unknown  university.degree
#   7796   yes  unknown  university.degree
#   27408  yes  unknown  university.degree
#   32799  yes  unknown  university.degree
#   32800  yes  unknown  university.degree
#   32802  yes  unknown  university.degree
#   32803  yes  unknown  university.degree
#   33946  yes  unknown  university.degree
#   36013  yes  unknown  university.degree
#   36236  yes  unknown  university.degree
#   36240  yes  unknown  university.degree),
#  (('yes', 'unknown', 'admin.'),
#            y     job education
#   1874   yes  admin.   unknown
#   7159   yes  admin.   unknown
#   10788  yes  admin.   unknown
#   15177  yes  admin.   unknown
#   15386  yes  admin.   unknown
#   16490  yes  admin.   unknown
#   17107  yes  admin.   unknown
#   26116  yes  admin.   unknown
#   32301  yes  admin.   unknown
#   32794  yes  admin.   unknown
#   33051  yes  admin.   unknown
#   33065  yes  admin.   unknown
#   33111  yes  admin.   unknown
#   33304  yes  admin.   unknown
#   33353  yes  admin.   unknown
#   34135  yes  admin.   unknown
#   34196  yes  admin.   unknown
#   34198  yes  admin.   unknown
#   34405  yes  admin.   unknown
#   34896  yes  admin.   unknown
#   34899  yes  admin.   unknown
#   34984  yes  admin.   unknown
#   35185  yes  admin.   unknown
#   35293  yes  admin.   unknown
#   35403  yes  admin.   unknown
#   35408  yes  admin.   unknown
#   35591  yes  admin.   unknown
#   35592  yes  admin.   unknown
#   35593  yes  admin.   unknown
#   35595  yes  admin.   unknown
#   35696  yes  admin.   unknown
#   35796  yes  admin.   unknown
#   36178  yes  admin.   unknown
#   36789  yes  admin.   unknown
#   37012  yes  admin.   unknown),
#  (('yes', 'unknown', 'blue-collar'),
#            y          job education
#   3578   yes  blue-collar   unknown
#   3839   yes  blue-collar   unknown
#   4486   yes  blue-collar   unknown
#   8958   yes  blue-collar   unknown
#   13613  yes  blue-collar   unknown
#   13715  yes  blue-collar   unknown
#   14460  yes  blue-collar   unknown
#   14719  yes  blue-collar   unknown
#   15381  yes  blue-collar   unknown
#   17432  yes  blue-collar   unknown
#   18943  yes  blue-collar   unknown
#   19017  yes  blue-collar   unknown
#   22450  yes  blue-collar   unknown
#   24781  yes  blue-collar   unknown
#   25878  yes  blue-collar   unknown
#   26010  yes  blue-collar   unknown
#   28869  yes  blue-collar   unknown
#   30704  yes  blue-collar   unknown
#   33166  yes  blue-collar   unknown
#   33375  yes  blue-collar   unknown
#   33653  yes  blue-collar   unknown
#   35424  yes  blue-collar   unknown
#   35612  yes  blue-collar   unknown
#   35688  yes  blue-collar   unknown),
#  (('yes', 'unknown', 'entrepreneur'),
#            y           job education
#   16242  yes  entrepreneur   unknown
#   29943  yes  entrepreneur   unknown
#   31627  yes  entrepreneur   unknown
#   33297  yes  entrepreneur   unknown),
#  (('yes', 'unknown', 'housemaid'),
#            y        job education
#   9258   yes  housemaid   unknown
#   25286  yes  housemaid   unknown
#   33523  yes  housemaid   unknown
#   33548  yes  housemaid   unknown
#   35778  yes  housemaid   unknown),
#  (('yes', 'unknown', 'management'),
#            y         job education
#   8033   yes  management   unknown
#   8310   yes  management   unknown
#   9951   yes  management   unknown
#   23815  yes  management   unknown
#   24110  yes  management   unknown
#   27058  yes  management   unknown
#   33160  yes  management   unknown
#   33670  yes  management   unknown
#   34180  yes  management   unknown
#   34949  yes  management   unknown
#   35115  yes  management   unknown
#   35119  yes  management   unknown
#   35120  yes  management   unknown
#   35171  yes  management   unknown
#   35539  yes  management   unknown
#   35587  yes  management   unknown
#   35713  yes  management   unknown
#   35756  yes  management   unknown
#   36397  yes  management   unknown),
#  (('yes', 'unknown', 'retired'),
#            y      job education
#   20509  yes  retired   unknown
#   25082  yes  retired   unknown
#   25480  yes  retired   unknown
#   25481  yes  retired   unknown
#   25494  yes  retired   unknown
#   25787  yes  retired   unknown
#   25883  yes  retired   unknown
#   26334  yes  retired   unknown
#   32293  yes  retired   unknown
#   33691  yes  retired   unknown
#   33816  yes  retired   unknown
#   34012  yes  retired   unknown
#   34229  yes  retired   unknown
#   34272  yes  retired   unknown
#   34470  yes  retired   unknown
#   34931  yes  retired   unknown
#   34945  yes  retired   unknown
#   34946  yes  retired   unknown
#   35279  yes  retired   unknown
#   35292  yes  retired   unknown
#   35417  yes  retired   unknown
#   35777  yes  retired   unknown
#   35919  yes  retired   unknown
#   35921  yes  retired   unknown
#   36154  yes  retired   unknown
#   36424  yes  retired   unknown
#   36441  yes  retired   unknown
#   36663  yes  retired   unknown
#   36666  yes  retired   unknown
#   36675  yes  retired   unknown),
#  (('yes', 'unknown', 'self-employed'),
#            y            job education
#   33271  yes  self-employed   unknown
#   36270  yes  self-employed   unknown),
#  (('yes', 'unknown', 'services'),
#            y       job education
#   5361   yes  services   unknown
#   13173  yes  services   unknown
#   13174  yes  services   unknown
#   14635  yes  services   unknown
#   15014  yes  services   unknown
#   20190  yes  services   unknown
#   24976  yes  services   unknown
#   26278  yes  services   unknown
#   26432  yes  services   unknown
#   26480  yes  services   unknown
#   32830  yes  services   unknown
#   33140  yes  services   unknown
#   35598  yes  services   unknown
#   35606  yes  services   unknown
#   35824  yes  services   unknown
#   35826  yes  services   unknown
#   36338  yes  services   unknown),
#  (('yes', 'unknown', 'student'),
#            y      job education
#   15563  yes  student   unknown
#   21688  yes  student   unknown
#   26016  yes  student   unknown
#   26106  yes  student   unknown
#   26362  yes  student   unknown
#   26497  yes  student   unknown
#   26502  yes  student   unknown
#   26763  yes  student   unknown
#   27005  yes  student   unknown
#   27029  yes  student   unknown
#   27319  yes  student   unknown
#   27419  yes  student   unknown
#   27566  yes  student   unknown
#   32866  yes  student   unknown
#   33091  yes  student   unknown
#   33165  yes  student   unknown
#   33229  yes  student   unknown
#   33337  yes  student   unknown
#   34013  yes  student   unknown
#   34014  yes  student   unknown
#   34068  yes  student   unknown
#   34146  yes  student   unknown
#   34161  yes  student   unknown
#   34458  yes  student   unknown
#   34617  yes  student   unknown
#   34983  yes  student   unknown
#   35024  yes  student   unknown
#   35109  yes  student   unknown
#   35396  yes  student   unknown
#   35404  yes  student   unknown
#   35406  yes  student   unknown
#   35409  yes  student   unknown
#   35410  yes  student   unknown
#   35463  yes  student   unknown
#   35629  yes  student   unknown
#   35630  yes  student   unknown
#   35638  yes  student   unknown
#   35649  yes  student   unknown
#   35662  yes  student   unknown
#   35675  yes  student   unknown
#   35769  yes  student   unknown
#   35770  yes  student   unknown
#   36081  yes  student   unknown
#   36082  yes  student   unknown
#   36207  yes  student   unknown
#   36356  yes  student   unknown
#   36362  yes  student   unknown
#   36378  yes  student   unknown
#   36380  yes  student   unknown
#   36520  yes  student   unknown
#   36613  yes  student   unknown
#   36763  yes  student   unknown
#   36855  yes  student   unknown),
#  (('yes', 'unknown', 'technician'),
#            y         job education
#   3038   yes  technician   unknown
#   6876   yes  technician   unknown
#   10764  yes  technician   unknown
#   15781  yes  technician   unknown
#   26382  yes  technician   unknown
#   27445  yes  technician   unknown
#   27720  yes  technician   unknown
#   30989  yes  technician   unknown
#   32521  yes  technician   unknown
#   33138  yes  technician   unknown
#   33984  yes  technician   unknown
#   34932  yes  technician   unknown
#   35139  yes  technician   unknown
#   35343  yes  technician   unknown
#   35347  yes  technician   unknown
#   36116  yes  technician   unknown
#   36117  yes  technician   unknown
#   36328  yes  technician   unknown
#   36453  yes  technician   unknown
#   37009  yes  technician   unknown
#   37020  yes  technician   unknown),
#  (('yes', 'unknown', 'unemployed'),
#            y         job education
#   23517  yes  unemployed   unknown
#   33469  yes  unemployed   unknown
#   33497  yes  unemployed   unknown
#   34244  yes  unemployed   unknown
#   36760  yes  unemployed   unknown),
#  (('yes', 'unknown', 'unknown'),
#            y      job education
#   344    yes  unknown   unknown
#   8041   yes  unknown   unknown
#   13344  yes  unknown   unknown
#   13345  yes  unknown   unknown
#   21601  yes  unknown   unknown
#   21670  yes  unknown   unknown
#   34097  yes  unknown   unknown
#   34157  yes  unknown   unknown
#   34238  yes  unknown   unknown
#   34400  yes  unknown   unknown
#   34831  yes  unknown   unknown
#   35922  yes  unknown   unknown
#   36280  yes  unknown   unknown
#   36353  yes  unknown   unknown
#   36403  yes  unknown   unknown
#   36608  yes  unknown   unknown)]

# %% [markdown]
# Analysis of the Impact of Loan on Response of Candidates

# %%
loan_analyse_n =  df4[["loan", "y"]].loc[(df4["loan"] == "no")]
loan_analyse_n
# Out:
#       loan    y
# 1       no   no
# 2       no   no
# 3       no   no
# 4       no   no
# 5       no   no
# ...    ...  ...
# 37079   no  yes
# 37080   no   no
# 37081   no   no
# 37082   no  yes
# 37083   no   no
#
# [30561 rows x 2 columns]

# %%
loan_analyse_n.value_counts()
# Out:
# loan  y
# no    no     27062
#       yes     3499
# dtype: int64

# %% [markdown]
# INFERENCE: Out of the candidates who did not have any loans, 3499 responded positively, while 27,062 of them responded with a 'No'.

# %% [markdown]
# #### Remove Graphs

# %%
loan_analyse.groupby('y').size().plot.pie(label='Response', autopct='%1.1f%%')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-07c80c9d8d22> in <module>
# ----> 1 loan_analyse.groupby('y').size().plot.pie(label='Response', autopct='%1.1f%%')
#
# NameError: name 'loan_analyse' is not defined

# %%
loan_analyse_y =  df4[["loan", "y"]].loc[(df4["loan"] == "yes")]
loan_analyse_y
# Out:
#       loan    y
# 0      yes   no
# 8      yes   no
# 11     yes   no
# 13     yes   no
# 14     yes   no
# ...    ...  ...
# 36999  yes  yes
# 37010  yes   no
# 37025  yes  yes
# 37041  yes   no
# 37074  yes   no
#
# [5641 rows x 2 columns]

# %%
loan_analyse_y.value_counts()
# Out:
# loan  y
# yes   no     5023
#       yes     618
# dtype: int64

# %% [markdown]
# INFERENCE: Out of the candidates who did have loans, 618 responded positively, while 5023 of them responded with a 'No'.

# %%
loan_analyse.groupby('y').size().plot.pie(label='Response', autopct='%1.1f%%')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-07c80c9d8d22> in <module>
# ----> 1 loan_analyse.groupby('y').size().plot.pie(label='Response', autopct='%1.1f%%')
#
# NameError: name 'loan_analyse' is not defined

# %% [markdown]
# Univariate Analysis based on 'loan' variable

# %%
analys_loan = df4.groupby(['loan', 'y'])['Customer_id'].count().unstack()
analys_loan
# Out:
# y           no   yes
# loan
# no       27062  3499
# unknown    791    91
# yes       5023   618

# %%
analys_loan.plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='loan'>

# %%
analys_loan.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='loan'>

# %% [markdown]
# Univariate Analysis based on 'job' variable

# %%
analys_job = df4.groupby(['job', 'y'])['Customer_id'].count().unstack()
analys_job
# Out:
# y                no   yes
# job
# admin.         8174  1246
# blue-collar    7738   576
# entrepreneur   1198   111
# housemaid       853    93
# management     2345   292
# retired        1146   395
# self-employed  1145   131
# services       3249   298
# student         527   240
# technician     5439   657
# unemployed      791   134
# unknown         271    35

# %%
analys_job.plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='job'>

# %%
analys_job.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='job'>

# %%
analys_educ = df4.groupby(['education', 'y'])['Customer_id'].count().unstack()
analys_educ
# Out:
# y                      no   yes
# education
# basic.4y             3374   391
# basic.6y             1903   171
# basic.9y             5001   420
# high.school          7597   945
# illiterate             14     2
# professional.course  4205   541
# university.degree    9464  1507
# unknown              1318   231

# %%
analys_educ.plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='education'>

# %%
analys_educ.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='education'>

# %% [markdown]
# TASK 1.1.5: Socio-Economical Analysis of the Customers

# %%
df5 = pd.merge(cust_resp_data, cust_social_eco_data, on='Customer_id', how='outer')
df5
# Out:
#        Customer_id    y  emp.var.rate  cons.price.idx  cons.conf.idx  \
# 0                1   no           1.1          93.994          -36.4
# 1                2   no           1.1          93.994          -36.4
# 2                3   no           1.1          93.994          -36.4
# 3                4   no           1.1          93.994          -36.4
# 4                5   no           1.1          93.994          -36.4
# ...            ...  ...           ...             ...            ...
# 37079        37080  yes          -1.1          94.767          -50.8
# 37080        37081   no          -1.1          94.767          -50.8
# 37081        37082   no          -1.1          94.767          -50.8
# 37082        37083  yes          -1.1          94.767          -50.8
# 37083        37084   no          -1.1          94.767          -50.8
#
#        euribor3m  nr.employed
# 0          4.857       5191.0
# 1          4.857       5191.0
# 2          4.857       5191.0
# 3          4.857       5191.0
# 4          4.857       5191.0
# ...          ...          ...
# 37079      1.028       4963.6
# 37080      1.028       4963.6
# 37081      1.028       4963.6
# 37082      1.028       4963.6
# 37083      1.028       4963.6
#
# [37084 rows x 7 columns]

# %%
analys_cpi = df5.groupby(['cons.price.idx', 'y'])['Customer_id'].count().unstack()
analys_cpi
# Out:
# y                 no  yes
# cons.price.idx
# 92.201           455  237
# 92.379           142   94
# 92.431           233  158
# 92.469           100   63
# 92.649           166  155
# 92.713            76   81
# 92.756             8    1
# 92.843           141  110
# 92.893          4742  480
# 92.963           392  237
# 93.075          1821  405
# 93.200          3098  168
# 93.369           100  136
# 93.444          4420  244
# 93.749            71   91
# 93.798            23   40
# 93.876            83  115
# 93.918          5616  369
# 93.994          6782  218
# 94.027            98  108
# 94.055           108  100
# 94.199           141  133
# 94.215           123  159
# 94.465          3778  171
# 94.601            95   81
# 94.767            64   54

# %% [markdown]
# Analysis based on the CPI variable

# %%
cpi_sort=df5.groupby(['cons.price.idx', 'y'])['Customer_id'].count().unstack().sort_values("yes", ascending=False)
cpi_sort
# Out:
# y                 no  yes
# cons.price.idx
# 92.893          4742  480
# 93.075          1821  405
# 93.918          5616  369
# 93.444          4420  244
# 92.963           392  237
# 92.201           455  237
# 93.994          6782  218
# 94.465          3778  171
# 93.200          3098  168
# 94.215           123  159
# 92.431           233  158
# 92.649           166  155
# 93.369           100  136
# 94.199           141  133
# 93.876            83  115
# 92.843           141  110
# 94.027            98  108
# 94.055           108  100
# 92.379           142   94
# 93.749            71   91
# 94.601            95   81
# 92.713            76   81
# 92.469           100   63
# 94.767            64   54
# 93.798            23   40
# 92.756             8    1

# %%
cpi_sort.plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='cons.price.idx'>

# %% [markdown]
# INFERENCE: The graph indicates that Consumer Price Index value of 93.994 produced the largest number of unsuccessful responses. While, the CPI value of 92.893 produced the largest number of successful responses.

# %% [markdown]
# Analysis on the basis of 'emp.var.rate'

# %%
analys_se = df5.groupby(['emp.var.rate', 'y'])['Customer_id'].count().unstack()
analys_se
# Out:
# y                no   yes
# emp.var.rate
# -3.4            541   407
# -3.0             76    81
# -2.9            947   537
# -1.8           6958  1337
# -1.7            329   367
# -1.1            300   268
# -0.2              8     1
# -0.1           3121   208
#  1.1           6782   218
#  1.4          13814   784

# %%
emp_sort=df5.groupby(['emp.var.rate', 'y'])['Customer_id'].count().unstack().sort_values("yes", ascending=False)
emp_sort
# Out:
# y                no   yes
# emp.var.rate
# -1.8           6958  1337
#  1.4          13814   784
# -2.9            947   537
# -3.4            541   407
# -1.7            329   367
# -1.1            300   268
#  1.1           6782   218
# -0.1           3121   208
# -3.0             76    81
# -0.2              8     1

# %% [markdown]
# INFERENCE: The number of people with epm.var.rate -1.8 showed more positive, successful response towards the campaign as opposed to people with other emp.var.rate.

# %%
analys_eur = df5.groupby(['euribor3m', 'y'])['Customer_id'].count().unstack()
analys_eur
# Out:
# y             no   yes
# euribor3m
# 0.634        2.0   6.0
# 0.635       20.0  21.0
# 0.636       10.0   3.0
# 0.637        1.0   4.0
# 0.638        1.0   5.0
# ...          ...   ...
# 4.967      560.0  30.0
# 4.968      835.0  54.0
# 4.970      153.0   3.0
# 5.000        4.0   3.0
# 5.045        4.0   5.0
#
# [314 rows x 2 columns]

# %%
eur_sort=df5.groupby(['euribor3m', 'y'])['Customer_id'].count().unstack().sort_values("yes", ascending=False)
eur_sort
# Out:
# y              no    yes
# euribor3m
# 4.962      2222.0  130.0
# 1.365       145.0  124.0
# 1.405       930.0  123.0
# 4.963      2129.0  114.0
# 1.266       644.0   94.0
# ...           ...    ...
# 3.853         1.0    NaN
# 3.879         1.0    NaN
# 3.901         1.0    NaN
# 4.733         2.0    NaN
# 4.956        20.0    NaN
#
# [314 rows x 2 columns]

# %% [markdown]
# INFERENCE: The number of people with eurobor3m 4.962 showed more positive, successful response towards the campaign as opposed to people with other euribor3m values.

# %% [markdown]
# TASK 1.1.6: Demographic analysis of the marketing campaign using the master files.

# %%
demographic = cust_and_bank_det.merge(cust_resp_data,on='Customer_id').merge(state_master, on='State_Code').merge(city_master, on='City_Code')

# %%
res = demographic.groupby(['State_Name', 'y'])['Customer_id'].count().unstack()
res = res.assign(ratio =(res["yes"]/(res["no"]+res["yes"])))
res = res.sort_values(["yes", "ratio"], ascending=(False, False))
display(res)
# Out:
# y                       no  yes     ratio
# State_Name
# California            6562  865  0.116467
# New York              3722  490  0.116334
# Texas                 3227  387  0.107084
# Washington            1648  233  0.123870
# Illinois              1593  219  0.120861
# Pennsylvania          1969  211  0.096789
# Ohio                  1545  187  0.107968
# Florida               1253  157  0.111348
# North Carolina         817  103  0.111957
# Michigan               865   94  0.098019
# Arizona                751   93  0.110190
# Georgia                607   85  0.122832
# Tennessee              575   83  0.126140
# Virginia               731   81  0.099754
# Colorado               603   78  0.114537
# Oregon                 388   72  0.156522
# Indiana                498   64  0.113879
# Kentucky               462   58  0.111538
# Maryland               339   55  0.139594
# Wisconsin              353   51  0.126238
# Massachusetts          444   47  0.095723
# Connecticut            262   41  0.135314
# New Jersey             438   41  0.085595
# Delaware               313   40  0.113314
# Minnesota              315   32  0.092219
# Louisiana              132   30  0.185185
# Rhode Island           174   30  0.147059
# Arkansas               201   29  0.126087
# Oklahoma               219   29  0.116935
# South Carolina         142   26  0.154762
# Mississippi            175   24  0.120603
# Alabama                211   24  0.102128
# Missouri               222   23  0.093878
# Utah                   187   18  0.087805
# Nebraska               121   15  0.110294
# Nevada                 125   14  0.100719
# Iowa                    96   13  0.119266
# New Hampshire           90   12  0.117647
# Idaho                   67   11  0.141026
# New Mexico             129   11  0.078571
# Kansas                  84    7  0.076923
# District of Columbia    34    6  0.150000
# North Dakota            22    4  0.153846
# Maine                   25    4  0.137931
# Vermont                 31    4  0.114286
# South Dakota            42    3  0.066667
# Montana                 53    2  0.036364
# Wyoming                  3    1  0.250000
# West Virginia           11    1  0.083333

# %%
demographic[demographic["State_Name"]=='California'].groupby(['City_Name', 'y'])['Customer_id'].count().unstack().sort_values("yes", ascending=False)
# Out:
# y                  no    yes
# City_Name
# Los Angeles    2448.0  333.0
# San Francisco  1691.0  215.0
# San Diego       557.0   81.0
# Anaheim          79.0   21.0
# San Jose        136.0   15.0
# ...               ...    ...
# San Mateo         4.0    NaN
# Santa Maria       4.0    NaN
# Sunnyvale        19.0    NaN
# Whittier          4.0    NaN
# Yucaipa           4.0    NaN
#
# [81 rows x 2 columns]

# %% [markdown]
# INFERENCE: It is found that California State has maximum turnout for favourable response with 856 people responding 'Yes'. Within California, Los Angeles has the maximum turnout with 333 people responding 'Yes'.

# %% [markdown]
# # Descriptive Statistics for Numerical and Categorical Data

# %%
df_f1=cust_and_bank_det.merge(cust_camp_det,on='Customer_id').merge(cust_resp_data,on='Customer_id').merge(cust_social_eco_data,on='Customer_id').merge(cust_post_code_det,on='Customer_id')
#df_f1.describe()

# %%
df_f1=cust_and_bank_det.merge(cust_camp_det,on='Customer_id').merge(cust_resp_data,on='Customer_id').merge(cust_social_eco_data,on='Customer_id').merge(cust_post_code_det,on='Customer_id')
df_f1
# Out:
#        Customer_id  age          job  marital            education  default  \
# 0                1   56     services  married          high.school       no
# 1                2   45     services  married             basic.9y  unknown
# 2                3   59       admin.  married  professional.course       no
# 3                4   41  blue-collar  married              unknown  unknown
# 4                5   24   technician   single  professional.course       no
# ...            ...  ...          ...      ...                  ...      ...
# 37079        37080   73      retired  married  professional.course       no
# 37080        37081   46  blue-collar  married  professional.course       no
# 37081        37082   56      retired  married    university.degree       no
# 37082        37083   44   technician  married  professional.course       no
# 37083        37084   74      retired  married  professional.course       no
#
#       housing loan Region_Code State_Code  ... pdays previous     poutcome  \
# 0          no  yes           3         S1  ...   999        0  nonexistent
# 1          no   no           3         S1  ...   999        0  nonexistent
# 2          no   no           4         S2  ...   999        0  nonexistent
# 3          no   no           3         S3  ...   999        0  nonexistent
# 4         yes   no           3         S3  ...   999        0  nonexistent
# ...       ...  ...         ...        ...  ...   ...      ...          ...
# 37079     yes   no           2        S16  ...   999        0  nonexistent
# 37080      no   no           2        S16  ...   999        0  nonexistent
# 37081     yes   no           2        S16  ...   999        0  nonexistent
# 37082      no   no           4        S17  ...   999        0  nonexistent
# 37083     yes   no           1         S6  ...   999        1      failure
#
#          y  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0       no           1.1          93.994          -36.4      4.857
# 1       no           1.1          93.994          -36.4      4.857
# 2       no           1.1          93.994          -36.4      4.857
# 3       no           1.1          93.994          -36.4      4.857
# 4       no           1.1          93.994          -36.4      4.857
# ...    ...           ...             ...            ...        ...
# 37079  yes          -1.1          94.767          -50.8      1.028
# 37080   no          -1.1          94.767          -50.8      1.028
# 37081   no          -1.1          94.767          -50.8      1.028
# 37082  yes          -1.1          94.767          -50.8      1.028
# 37083   no          -1.1          94.767          -50.8      1.028
#
#       nr.employed Postal Code
# 0          5191.0       42420
# 1          5191.0       42420
# 2          5191.0       90036
# 3          5191.0       33311
# 4          5191.0       33311
# ...           ...         ...
# 37079      4963.6       10009
# 37080      4963.6       10011
# 37081      4963.6       10009
# 37082      4963.6       85254
# 37083      4963.6       79109
#
# [37084 rows x 26 columns]

# %%
df_f1["y"].value_counts()
# Out:
# no     32876
# yes     4208
# Name: y, dtype: int64

# %%
df_f1["y"].describe()
# Out:
# count     37084
# unique        2
# top          no
# freq      32876
# Name: y, dtype: object

# %%
df_f1["y"].mode()
# Out:
# 0    no
# dtype: object

# %%
df_f1["age"].value_counts()
# Out:
# 31    1761
# 33    1656
# 32    1644
# 36    1627
# 35    1584
#       ...
# 98       2
# 89       2
# 91       2
# 94       1
# 95       1
# Name: age, Length: 77, dtype: int64

# %%
df_f1["age"].describe()
# Out:
# count    37084.000000
# mean        40.042714
# std         10.432965
# min         17.000000
# 25%         32.000000
# 50%         38.000000
# 75%         47.000000
# max         98.000000
# Name: age, dtype: float64

# %%
df_f1["age"].mode()
# Out:
# 0    31
# dtype: int64

# %%
df_f1["previous"].mode()
# Out:
# 0    0
# dtype: int64

# %%
df_f1.shape
# Out:
# (37084, 26)

# %%
df_f1.head(10)
# Out:
#    Customer_id  age          job   marital            education  default  \
# 0            1   56     services   married          high.school       no
# 1            2   45     services   married             basic.9y  unknown
# 2            3   59       admin.   married  professional.course       no
# 3            4   41  blue-collar   married              unknown  unknown
# 4            5   24   technician    single  professional.course       no
# 5            6   25     services    single          high.school       no
# 6            7   41  blue-collar   married              unknown  unknown
# 7            8   25     services    single          high.school       no
# 8            9   29  blue-collar    single          high.school       no
# 9           10   57    housemaid  divorced             basic.4y       no
#
#   housing loan Region_Code State_Code  ... pdays previous     poutcome   y  \
# 0      no  yes           3         S1  ...   999        0  nonexistent  no
# 1      no   no           3         S1  ...   999        0  nonexistent  no
# 2      no   no           4         S2  ...   999        0  nonexistent  no
# 3      no   no           3         S3  ...   999        0  nonexistent  no
# 4     yes   no           3         S3  ...   999        0  nonexistent  no
# 5     yes   no           4         S2  ...   999        0  nonexistent  no
# 6      no   no           4         S2  ...   999        0  nonexistent  no
# 7     yes   no           4         S2  ...   999        0  nonexistent  no
# 8      no  yes           4         S2  ...   999        0  nonexistent  no
# 9     yes   no          Na         S2  ...   999        0  nonexistent  no
#
#    emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m nr.employed  \
# 0           1.1          93.994          -36.4      4.857      5191.0
# 1           1.1          93.994          -36.4      4.857      5191.0
# 2           1.1          93.994          -36.4      4.857      5191.0
# 3           1.1          93.994          -36.4      4.857      5191.0
# 4           1.1          93.994          -36.4      4.857      5191.0
# 5           1.1          93.994          -36.4      4.857      5191.0
# 6           1.1          93.994          -36.4      4.857      5191.0
# 7           1.1          93.994          -36.4      4.857      5191.0
# 8           1.1          93.994          -36.4      4.857      5191.0
# 9           1.1          93.994          -36.4      4.857      5191.0
#
#   Postal Code
# 0       42420
# 1       42420
# 2       90036
# 3       33311
# 4       33311
# 5       90032
# 6       90032
# 7       90032
# 8       90032
# 9       90032
#
# [10 rows x 26 columns]

# %%
df_f1.tail()
# Out:
#        Customer_id  age          job  marital            education default  \
# 37079        37080   73      retired  married  professional.course      no
# 37080        37081   46  blue-collar  married  professional.course      no
# 37081        37082   56      retired  married    university.degree      no
# 37082        37083   44   technician  married  professional.course      no
# 37083        37084   74      retired  married  professional.course      no
#
#       housing loan Region_Code State_Code  ... pdays previous     poutcome  \
# 37079     yes   no           2        S16  ...   999        0  nonexistent
# 37080      no   no           2        S16  ...   999        0  nonexistent
# 37081     yes   no           2        S16  ...   999        0  nonexistent
# 37082      no   no           4        S17  ...   999        0  nonexistent
# 37083     yes   no           1         S6  ...   999        1      failure
#
#          y  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 37079  yes          -1.1          94.767          -50.8      1.028
# 37080   no          -1.1          94.767          -50.8      1.028
# 37081   no          -1.1          94.767          -50.8      1.028
# 37082  yes          -1.1          94.767          -50.8      1.028
# 37083   no          -1.1          94.767          -50.8      1.028
#
#       nr.employed Postal Code
# 37079      4963.6       10009
# 37080      4963.6       10011
# 37081      4963.6       10009
# 37082      4963.6       85254
# 37083      4963.6       79109
#
# [5 rows x 26 columns]

# %%
df_f1["job"].mode()
# Out:
# 0    admin.
# dtype: object

# %%
df_f1['job'].describe()
# Out:
# count      37084
# unique        12
# top       admin.
# freq        9420
# Name: job, dtype: object

# %%
df_f1["marital"].mode()
# Out:
# 0    married
# dtype: object

# %%
df_f1["education"].mode()
# Out:
# 0    university.degree
# dtype: object

# %%
df_f1["housing"].mode()
# Out:
# 0    yes
# dtype: object

# %%
df_f1["loan"].mode()
# Out:
# 0    no
# dtype: object

# %%
df_f1["campaign"].mode()
# Out:
# 0    1
# dtype: int64

# %%
df_f1["cons.price.idx"].mode()
# Out:
# 0    93.994
# dtype: float64

# %%
df_f1["y"].count()
# Out:
# 37084

# %%
df_f1["age"].skew()
# Out:
# 0.7911491055381439

# %%
df_f1["age"].kurtosis()
# Out:
# 0.8197516247007814

# %%
q1=np.percentile(df_f1["age"],25)
q1
# Out:
# 32.0

# %%
q3=np.percentile(df_f1["age"],75)
q3
# Out:
# 47.0

# %%
iqrr=q3-q1
iqrr
# Out:
# 15.0

# %%
upperr=q3 +1.5*(iqrr)
lowerr=q1-(1.5*(iqrr))
print(upperr,lowerr)
# Out:
# 69.5 9.5

# %%
f1=df_f1[(df_f1["age"]>upperr) |(df_f1["age"]<lowerr)]  #outliers
f1
# Out:
#        Customer_id  age      job   marital            education  default  \
# 24956        24957   70  retired  divorced             basic.4y       no
# 24996        24997   76  retired   married    university.degree       no
# 25016        25017   73  retired   married    university.degree       no
# 25034        25035   88  retired  divorced             basic.4y       no
# 25036        25037   88  retired  divorced             basic.4y       no
# ...            ...  ...      ...       ...                  ...      ...
# 36904        36905   84  retired  divorced             basic.4y  unknown
# 36911        36912   81  retired   married             basic.4y       no
# 36919        36920   80  retired   married  professional.course       no
# 37079        37080   73  retired   married  professional.course       no
# 37083        37084   74  retired   married  professional.course       no
#
#       housing loan Region_Code State_Code  ... pdays previous     poutcome  \
# 24956     yes   no           2        S35  ...   999        0  nonexistent
# 24996      no  yes           2        S10  ...   999        0  nonexistent
# 25016     yes   no           1        S11  ...   999        1      failure
# 25034     yes   no           4         S2  ...   999        0  nonexistent
# 25036      no   no           1        S11  ...   999        0  nonexistent
# ...       ...  ...         ...        ...  ...   ...      ...          ...
# 36904     yes  yes           3        S20  ...     3        1      success
# 36911     yes   no           4         S2  ...   999        2      failure
# 36919     yes   no           1         S6  ...   999        1      failure
# 37079     yes   no           2        S16  ...   999        0  nonexistent
# 37083     yes   no           1         S6  ...   999        1      failure
#
#          y  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 24956  yes          -1.8          92.843          -50.0      1.811
# 24996   no          -1.8          92.843          -50.0      1.757
# 25016   no          -1.8          92.843          -50.0      1.687
# 25034   no          -1.8          92.843          -50.0      1.663
# 25036  yes          -1.8          92.843          -50.0      1.663
# ...    ...           ...             ...            ...        ...
# 36904   no          -1.1          94.601          -49.5      1.000
# 36911  yes          -1.1          94.601          -49.5      1.016
# 36919  yes          -1.1          94.601          -49.5      1.025
# 37079  yes          -1.1          94.767          -50.8      1.028
# 37083   no          -1.1          94.767          -50.8      1.028
#
#       nr.employed Postal Code
# 24956      5099.1        2908
# 24996      5099.1       19134
# 25016      5099.1       60653
# 25034      5099.1       90036
# 25036      5099.1       60610
# ...           ...         ...
# 36904      4963.6       36830
# 36911      4963.6       94109
# 36919      4963.6       79907
# 37079      4963.6       10009
# 37083      4963.6       79109
#
# [429 rows x 26 columns]

# %%
sns.boxplot(df_f1["age"])
# Out:
# C:\Users\iraghupathivasish\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age'>

# %% [markdown]
# Finding any outliers using z method

# %%
mu=df_f1["age"].mean()
var=df_f1["age"].var()
sigma=np.sqrt(var)
upper_bound=mu+ 3*sigma
lower_bound=mu- 3*sigma
df_f1[(df_f1['age']>upper_bound)| (df_f1['age']<lower_bound)]
# Out:
#        Customer_id  age      job   marital            education  default  \
# 24996        24997   76  retired   married    university.degree       no
# 25016        25017   73  retired   married    university.degree       no
# 25034        25035   88  retired  divorced             basic.4y       no
# 25036        25037   88  retired  divorced             basic.4y       no
# 25038        25039   88  retired  divorced             basic.4y       no
# ...            ...  ...      ...       ...                  ...      ...
# 36904        36905   84  retired  divorced             basic.4y  unknown
# 36911        36912   81  retired   married             basic.4y       no
# 36919        36920   80  retired   married  professional.course       no
# 37079        37080   73  retired   married  professional.course       no
# 37083        37084   74  retired   married  professional.course       no
#
#       housing loan Region_Code State_Code  ... pdays previous     poutcome  \
# 24996      no  yes           2        S10  ...   999        0  nonexistent
# 25016     yes   no           1        S11  ...   999        1      failure
# 25034     yes   no           4         S2  ...   999        0  nonexistent
# 25036      no   no           1        S11  ...   999        0  nonexistent
# 25038     yes  yes           4         S5  ...   999        0  nonexistent
# ...       ...  ...         ...        ...  ...   ...      ...          ...
# 36904     yes  yes           3        S20  ...     3        1      success
# 36911     yes   no           4         S2  ...   999        2      failure
# 36919     yes   no           1         S6  ...   999        1      failure
# 37079     yes   no           2        S16  ...   999        0  nonexistent
# 37083     yes   no           1         S6  ...   999        1      failure
#
#          y  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 24996   no          -1.8          92.843          -50.0      1.757
# 25016   no          -1.8          92.843          -50.0      1.687
# 25034   no          -1.8          92.843          -50.0      1.663
# 25036  yes          -1.8          92.843          -50.0      1.663
# 25038  yes          -1.8          92.843          -50.0      1.663
# ...    ...           ...             ...            ...        ...
# 36904   no          -1.1          94.601          -49.5      1.000
# 36911  yes          -1.1          94.601          -49.5      1.016
# 36919  yes          -1.1          94.601          -49.5      1.025
# 37079  yes          -1.1          94.767          -50.8      1.028
# 37083   no          -1.1          94.767          -50.8      1.028
#
#       nr.employed Postal Code
# 24996      5099.1       19134
# 25016      5099.1       60653
# 25034      5099.1       90036
# 25036      5099.1       60610
# 25038      5099.1       98198
# ...           ...         ...
# 36904      4963.6       36830
# 36911      4963.6       94109
# 36919      4963.6       79907
# 37079      4963.6       10009
# 37083      4963.6       79109
#
# [336 rows x 26 columns]

# %%
df_f1["education"].value_counts()
# Out:
# university.degree      10971
# high.school             8542
# basic.9y                5421
# professional.course     4746
# basic.4y                3765
# basic.6y                2074
# unknown                 1549
# illiterate                16
# Name: education, dtype: int64

# %%
df_f1["education"].describe()
# Out:
# count                 37084
# unique                    8
# top       university.degree
# freq                  10971
# Name: education, dtype: object

# %% [markdown]
# # Statistical Hypothesis Testing

# %% [markdown]
# ### Z-Test

# %%
s1=cust_and_bank_det.sample(frac=0.1)
type(s1)
# Out:
# pandas.core.frame.DataFrame

# %%
#H0= POPULATION AGE MEAN SAME AS SAMPLE AGE MEAN  
#z test
import pandas as pd
from scipy import stats
from statsmodels.stats import weightstats as stests
ztest ,pval = stests.ztest(s1['age'],value=cust_and_bank_det["age"].mean())
print("p-value = ", float(pval))
if pval<0.05:
    print("Reject Null Hypothesis")
else:
    print("Accept Null Hypothesis")
# Out:
# p-value =  0.39158994335376274
# Accept Null Hypothesis

# %%
import math
import numpy as np
from numpy.random import randn
from statsmodels.stats.weightstats import ztest
  
# Generate a random array of 50 numbers having mean 110 and sd 15
# similar to the IQ scores data we assume above
mean_iq = 110
sd_iq = 15/math.sqrt(50)
alpha =0.05
null_mean =100
data = sd_iq*randn(50)+mean_iq
# print mean and sd
print('mean=%.2f stdv=%.2f' % (np.mean(data), np.std(data)))
  
# now we perform the test. In this function, we passed data, in the value parameter
# we passed mean value in the null hypothesis, in alternative hypothesis we check whether the
# mean is larger
  
ztest_Score, p_value= ztest(data,value = null_mean, alternative='larger')
# the function outputs a p_value and z-score corresponding to that value, we compare the 
# p-value with alpha, if it is greater than alpha then we do not null hypothesis 
# else we reject it.
  
if(p_value <  alpha):
  print("Reject Null Hypothesis")
else:
  print("Fail to Reject NUll Hypothesis")
# Out:
# mean=109.98 stdv=1.97
# Reject Null Hypothesis

# %% [markdown]
# ### Chi-Square Test

# %% [markdown]
# H0 = There is no relation between Marital Status  and the Education Status.

# %% [markdown]
# H1 = There is a significant relationship between Marital Status and the Education Status.

# %%
from scipy.stats import chi2_contingency
import seaborn as sns
import matplotlib.pyplot as plt
contingency= pd.crosstab(df_f1['education'], df_f1['marital'])
contingency
# Out:
# marital              divorced  married  single  unknown
# education
# basic.4y                  430     2918     412        5
# basic.6y                  164     1594     311        5
# basic.9y                  497     3728    1189        7
# high.school              1069     4659    2803       11
# illiterate                  1       14       1        0
# professional.course       600     2853    1287        6
# university.degree        1198     5775    3969       29
# unknown                   167      938     435        9

# %%
stat, p, dof, expected= chi2_contingency(contingency)
print("p-value = ", p)
if p<0.05:
    print("Reject Null Hypothesis")
else:
    print("Accept Null Hypothesis")
#c, p, dof, expected = chi2_contingency(contigency_1)
# Out:
# p-value =  1.20180058372557e-305
# Reject Null Hypothesis

# %%
from scipy.stats import chi2_contingency
import seaborn as sns
import matplotlib.pyplot as plt
contingency_y= pd.crosstab(df_f1['education'], df_f1['y'])
contingency_y
# Out:
# y                      no   yes
# education
# basic.4y             3374   391
# basic.6y             1903   171
# basic.9y             5001   420
# high.school          7597   945
# illiterate             14     2
# professional.course  4205   541
# university.degree    9464  1507
# unknown              1318   231

# %%
stat, p, dof, expected= chi2_contingency(contingency_y)
print("p-value = ", p)
if p<0.05:
    print("Reject Null Hypothesis")
else:
    print("Accept Null Hypothesis")
#c, p, dof, expected = chi2_contingency(contigency_1)
# Out:
# p-value =  1.598620634752338e-34
# Reject Null Hypothesis

# %%
from scipy.stats import chi2_contingency
from scipy.stats import chi2
contingency= pd.crosstab(df_f1['education'], df_f1['marital'])
stat, p, dof, expected = chi2_contingency(contingency)
print('dof=%d' % dof)
print(expected)
# interpret test-statistic
prob = 0.95
critical = chi2.ppf(prob, dof)
print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
    print('Dependent (reject H0)')
else:
    print('Independent (fail to reject H0)')
# interpret p-value
alpha = 1.0 - prob
print('significance=%.3f, p=%.3f' % (alpha, p))
if p <= alpha:
    print('Dependent (Reject H0)')
else:
    print('Independent (Fail to Reject H0)')
# Out:
# dof=21
# [[4.18897368e+02 2.28220890e+03 1.05658384e+03 7.30989106e+00]
#  [2.30755150e+02 1.25718493e+03 5.82033168e+02 4.02675008e+00]
#  [6.03145454e+02 3.28601712e+03 1.52131234e+03 1.05250782e+01]
#  [9.50390788e+02 5.17785616e+03 2.39716843e+03 1.65846187e+01]
#  [1.78017474e+00 9.69863014e+00 4.49013051e+00 3.10646101e-02]
#  [5.28044332e+02 2.87685616e+03 1.33188496e+03 9.21453996e+00]
#  [1.22064357e+03 6.65022945e+03 3.07882637e+03 2.13006148e+01]
#  [1.72343167e+02 9.38948630e+02 4.34700760e+02 3.00744256e+00]]
# probability=0.950, critical=32.671, stat=1502.162
# Dependent (reject H0)
# significance=0.050, p=0.000
# Dependent (Reject H0)

# %% [markdown]
# INFERENCE: The above hypothesis test indicates that the null hypothesis has been rejected, implying that there is a significant correlation between marital status and education.

# %% [markdown]
# ### Anova Test

# %%
df_f1.columns

# %%
df_f1['duration'].describe()
